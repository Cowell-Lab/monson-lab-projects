# %% [markdown]
# # Imports

# %%
import json
import airr
from make_jobs import create_vdjpipe_job_files
from make_jobs import create_igblast_job_file
from make_jobs import create_repcalc_job_file
# Out:
# /home/s236922/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/airr/schema.py:10: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream

# %% [markdown]
# # Data

# %%
# VDJ Pipe
project_id='c0aef9ef-362d-46fd-abba-39ac0945bd66'

data = airr.read_airr('./repertoires.airr.json')

# %% [markdown]
# # VDJ Pipe

# %%
vdjpipe_jobs = create_vdjpipe_job_files(data, project_id, 'COVVAX')

# %% [markdown]
# # IgBlast

# %%
job_uuid_dict = {
    '17' : '042a3a3b-3e36-4ad8-974e-56c496e09f60-007',
    '18' : '477a4a12-c9e3-43f1-9ece-410c9749f375-007',
    '19' : '1dabd696-fd52-4ec3-9c03-23a43add12ab-007',
    '20' : 'b47793f3-9959-4c00-94ad-4c24377deb0b-007',
    '22' : '1a9be174-00d4-427f-bf4a-9716ac566b53-007'
    # '17' : '7c6f533b-648c-48f0-b755-ca69fbfb7a67-007',
    # '18' : '006384d5-17e7-4063-8a81-0f1ade60f9cd-007',
    # '19' : 'cf9d976f-f329-4a12-b0bb-9bf7a0d66027-007',
    # '20' : '4b428d92-75c7-4974-89ac-5570ac88bccc-007',
    # '22' : '8a1a1a3b-32ba-4f3f-94a4-e9b58549f612-007'
}

igblast_job = create_igblast_job_file(data, project_id, job_uuid_dict, 'COVVAX')

# %% [markdown]
# # Repcalc

# %%
# job_id = 'e4513a1b-a267-4c1d-9f3d-35ed935f8f04-007' # <- previous igblast v 0.3 for prior to rearangment filter
job_id = 'ded5d21b-d4b5-44af-bbb5-096de9fc6eb3-007' # <- igblast v 0.5 with RF filter

repcalc_job = create_repcalc_job_file(data, project_id, job_id, 'COVVAX')

# %% [markdown]
# # Scratch

# %%
# job_id='403ed03c-4b11-47f4-b8be-974c16185149-007'

# vdjpipe jobs
# {seq_run_id: job_uuid, ...}



# lib_nums = set([rep['sample'][0]['sequencing_run_id'] for rep in data['Repertoire']])
# file_names = ['job-COVVAX-test-library-'+lib_num+'.json' for lib_num in lib_nums]

# json_contents = create_vdjpipe_job_files(data, project_id, False)

# %%
def find_duplicates(reps):
    seen = set(reps['subjects'])
    duplicates = set()
    for item in reps:
        if item in seen:
            duplicates.add(item)
        else:
            seen.add(item)
    return list(duplicates)

find_duplicates(data['Repertoire'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 [rep['subject']['subject_id'] for rep in data['Repertoire']].count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %% [markdown]
# # Parse JSON

# %%
data = '[{"name": "AIRRMetadata", "notes": "{}", "envKey": "AIRRMetadata", "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/files/repertoires.airr.json", "targetPath": "repertoires.airr.json", "description": null, "autoMountLocal": true, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "igblast_image", "notes": "{}", "envKey": "igblast_image", "optional": false, "sourceUrl": "tapis://data-storage.vdjserver.org/singularity/igblast-1.20.0.sif", "targetPath": "igblast-1.20.0.sif", "description": null, "autoMountLocal": true, "srcSharedAppCtx": "vdj", "destSharedAppCtx": "vdj"}, {"name": "repcalc_image", "notes": "{}", "envKey": "repcalc_image", "optional": false, "sourceUrl": "tapis://data-storage.vdjserver.org/singularity/repcalc-2.0-imm4.4.sif", "targetPath": "repcalc-2.0-imm4.4.sif", "description": null, "autoMountLocal": true, "srcSharedAppCtx": "vdj", "destSharedAppCtx": "vdj"}, {"name": "germline_db", "notes": "{}", "envKey": "germline_db", "optional": false, "sourceUrl": "tapis://data-storage.vdjserver.org/irplus/data/germline/vdjserver_human_germline.airr.json", "targetPath": "vdjserver_human_germline.airr.json", "description": null, "autoMountLocal": true, "srcSharedAppCtx": "vdj", "destSharedAppCtx": "vdj"}, {"name": "query_1.1", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/477a4a12-c9e3-43f1-9ece-410c9749f375-007/4490_S16_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4490_S16_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.2", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/477a4a12-c9e3-43f1-9ece-410c9749f375-007/4492_S1_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4492_S1_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.3", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/4505_S48_R1_001.fastq.merged.unique.fasta", "targetPath": "./4505_S48_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.4", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4518_S41_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4518_S41_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.5", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/477a4a12-c9e3-43f1-9ece-410c9749f375-007/4538_S17_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4538_S17_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.6", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/1dabd696-fd52-4ec3-9c03-23a43add12ab-007/4539_S47_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4539_S47_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.7", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/477a4a12-c9e3-43f1-9ece-410c9749f375-007/4540_S19_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4540_S19_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.8", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/477a4a12-c9e3-43f1-9ece-410c9749f375-007/4543_S20_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4543_S20_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.9", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4569_S20_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4569_S20_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.10", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4573_S21_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4573_S21_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.11", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/477a4a12-c9e3-43f1-9ece-410c9749f375-007/4574_S2_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4574_S2_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.12", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4575_S1_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4575_S1_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.13", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/1dabd696-fd52-4ec3-9c03-23a43add12ab-007/4577_S19_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4577_S19_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.14", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/477a4a12-c9e3-43f1-9ece-410c9749f375-007/4578_S3_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4578_S3_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.15", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4587_S42_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4587_S42_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.16", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/4592_S34_R1_001.fastq.merged.unique.fasta", "targetPath": "./4592_S34_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.17", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/4593_S35_R1_001.fastq.merged.unique.fasta", "targetPath": "./4593_S35_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.18", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/4594_S36_R1_001.fastq.merged.unique.fasta", "targetPath": "./4594_S36_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.19", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/4595_S37_R1_001.fastq.merged.unique.fasta", "targetPath": "./4595_S37_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.20", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4599_S16_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4599_S16_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.21", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/1a9be174-00d4-427f-bf4a-9716ac566b53-007/4600_S34_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4600_S34_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.22", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4603_S43_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4603_S43_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.23", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/4605_S38_R1_001.fastq.merged.unique.fasta", "targetPath": "./4605_S38_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.24", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/4613_S49_R1_001.fastq.merged.unique.fasta", "targetPath": "./4613_S49_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.25", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4615_S2_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4615_S2_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.26", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/4618_S50_R1_001.fastq.merged.unique.fasta", "targetPath": "./4618_S50_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.27", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/4621_S26_R1_001.fastq.merged.unique.fasta", "targetPath": "./4621_S26_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.28", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/477a4a12-c9e3-43f1-9ece-410c9749f375-007/4625_S21_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4625_S21_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.29", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4632_S3_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4632_S3_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.30", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4633_S17_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4633_S17_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.31", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4638_S35_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4638_S35_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.32", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4644_S36_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4644_S36_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.33", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/4649_S39_R1_001.fastq.merged.unique.fasta", "targetPath": "./4649_S39_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.34", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4653_S37_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4653_S37_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.35", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/4658_S47_R1_001.fastq.merged.unique.fasta", "targetPath": "./4658_S47_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.36", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/4659_S40_R1_001.fastq.merged.unique.fasta", "targetPath": "./4659_S40_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.37", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/477a4a12-c9e3-43f1-9ece-410c9749f375-007/4664_S12_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4664_S12_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.38", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4670_S4_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4670_S4_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.39", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/477a4a12-c9e3-43f1-9ece-410c9749f375-007/4674_S4_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4674_S4_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.40", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/1a9be174-00d4-427f-bf4a-9716ac566b53-007/4675_S30_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4675_S30_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.41", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/1a9be174-00d4-427f-bf4a-9716ac566b53-007/4677_S35_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4677_S35_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.42", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/042a3a3b-3e36-4ad8-974e-56c496e09f60-007/4678_S39_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./4678_S39_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1
L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./5187_S7_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.162", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/5189_S18_R1_001.fastq.merged.unique.fasta", "targetPath": "./5189_S18_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.163", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/5190_S19_R1_001.fastq.merged.unique.fasta", "targetPath": "./5190_S19_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.164", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/5191_S20_R1_001.fastq.merged.unique.fasta", "targetPath": "./5191_S20_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.165", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/1dabd696-fd52-4ec3-9c03-23a43add12ab-007/5194_S10_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./5194_S10_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.166", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/1dabd696-fd52-4ec3-9c03-23a43add12ab-007/5199_S11_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./5199_S11_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.167", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/5200_S21_R1_001.fastq.merged.unique.fasta", "targetPath": "./5200_S21_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.168", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/1dabd696-fd52-4ec3-9c03-23a43add12ab-007/5204_S12_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./5204_S12_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.169", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/5205_S29_R1_001.fastq.merged.unique.fasta", "targetPath": "./5205_S29_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.170", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/5206_S22_R1_001.fastq.merged.unique.fasta", "targetPath": "./5206_S22_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.171", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/5207_S23_R1_001.fastq.merged.unique.fasta", "targetPath": "./5207_S23_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.172", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/5210_S24_R1_001.fastq.merged.unique.fasta", "targetPath": "./5210_S24_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.173", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/5212_S25_R1_001.fastq.merged.unique.fasta", "targetPath": "./5212_S25_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.174", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/5217_S30_R1_001.fastq.merged.unique.fasta", "targetPath": "./5217_S30_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.175", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/1a9be174-00d4-427f-bf4a-9716ac566b53-007/5219_S44_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./5219_S44_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.176", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/1a9be174-00d4-427f-bf4a-9716ac566b53-007/5220_S31_L001_R1_001.fastq.merged.unique.fasta", "targetPath": "./5220_S31_L001_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}, {"name": "_1.177", "notes": "{}", "envKey": null, "optional": true, "sourceUrl": "tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/analyses/b47793f3-9959-4c00-94ad-4c24377deb0b-007/5221_S33_R1_001.fastq.merged.unique.fasta", "targetPath": "./5221_S33_R1_001.fastq.merged.unique.fasta", "description": null, "autoMountLocal": false, "srcSharedAppCtx": "", "destSharedAppCtx": "vdj"}]'

# %%
data = '[{"name": "Alice"}, {"name": "Bob"}]'

# %%
parsed = json.loads(data)

# %%
for e in parsed:
    print(e)
# Out:
# {'name': 'AIRRMetadata', 'notes': '{}', 'envKey': 'AIRRMetadata', 'optional': True, 'sourceUrl': 'tapis://data-storage.vdjserver.org/projects/c0aef9ef-362d-46fd-abba-39ac0945bd66/files/repertoires.airr.json', 'targetPath': 'repertoires.airr.json', 'description': None, 'autoMountLocal': True, 'srcSharedAppCtx': '', 'destSharedAppCtx': 'vdj'}
# {'name': 'igblast_image', 'notes': '{}', 'envKey': 'igblast_image', 'optional': False, 'sourceUrl': 'tapis://data-storage.vdjserver.org/singularity/igblast-1.20.0.sif', 'targetPath': 'igblast-1.20.0.sif', 'description': None, 'autoMountLocal': True, 'srcSharedAppCtx': 'vdj', 'destSharedAppCtx': 'vdj'}
# {'name': 'repcalc_image', 'notes': '{}', 'envKey': 'repcalc_image', 'optional': False, 'sourceUrl': 'tapis://data-storage.vdjserver.org/singularity/repcalc-2.0-imm4.4.sif', 'targetPath': 'repcalc-2.0-imm4.4.sif', 'description': None, 'autoMountLocal': True, 'srcSharedAppCtx': 'vdj', 'destSharedAppCtx': 'vdj'}
# ...
