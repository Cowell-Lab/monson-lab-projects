# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
# matplotlib
import matplotlib as mpl
from matplotlib.axes import Axes
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.gridspec import GridSpec
from matplotlib.text import Text
from matplotlib.ticker import FixedLocator, MultipleLocator, MaxNLocator
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# others
import airr
import colorspacious as cs
import numpy as np
import pandas as pd
import seaborn as sns
from tabulate import tabulate

# add repertoire_zoo
import sys
pkg_path = '/mnt/md0/s236922/cowell-lab/repertoire_zoo/' # /path/to/repertoire_zoo/
sys.path.append(pkg_path)
import repertoire_zoo.bird as br
import repertoire_zoo.giraffe as gr

# %% [markdown]
# ## Helper Functions

# %%
def cat_to_pos(axes:list):
    all_categories = set()
    for ax in axes:
        labels = [tick.get_text() for tick in ax.get_xticklabels()]
        all_categories.update(labels)

    # all_categories = sorted(all_categories)
    cat_pos = {cat: i for i, cat in enumerate(all_categories)}

    return cat_pos, all_categories

def remap_categories(ax, cat_pos):
    # remap bars
    for patch in ax.patches:
        label = patch.get_x() + patch.get_width() / 2
        print(patch, label, cat_pos.values())
        # This assumes label matches integer index; you’d need a mapping
        if label in cat_pos.values():
            new_x = list(cat_pos.values()).index(label)
            patch.set_x(new_x - patch.get_width() / 2)

    # remap scatter points (if strip/swarmplot used)
    for coll in ax.collections:
        offsets = coll.get_offsets()
        for i, (x, y) in enumerate(offsets):
            if x in cat_pos.values():
                new_x = list(cat_pos.values()).index(x)
                offsets[i, 0] = new_x
        coll.set_offsets(offsets)

def ensure_categories(df, x_col, categories, y_col=None, fill_value=0):
    """
    Ensure that all categories appear in the DataFrame.
    
    Parameters
    ----------
    df : pd.DataFrame
        Original data
    x_col : str
        Column used for x-axis (categories)
    categories : list
        Full list of categories to appear in plot
    y_col : str or None
        Column used for values (for bar height). If None, placeholder rows won't include y_col
    fill_value : numeric, default 0
        Value to fill for missing categories
    """
    missing = [cat for cat in categories if cat not in df[x_col].unique()]
    if not missing:
        return df

    # Create placeholder rows
    placeholder_rows = []
    for cat in missing:
        row = {x_col: cat}
        if y_col is not None:
            row[y_col] = fill_value
        placeholder_rows.append(row)

    df_placeholders = pd.DataFrame(placeholder_rows)

    # Concatenate
    df_full = pd.concat([df, df_placeholders], ignore_index=True)
    
    return df_full

def remap_bars(ax, cat_pos):
    patches = [p for p in ax.patches if hasattr(p, "get_x")]
    if not patches:
        return

    # tick labels and their current center positions
    tick_labels = [t.get_text() for t in ax.get_xticklabels()]
    centers = [round(p.get_x() + p.get_width() / 2, 6) for p in patches]

    # map old centers -> category labels
    old_centers = sorted(set(centers))
    old_map = dict(zip(old_centers, tick_labels))

    # group patches by old center
    grouped = {c: [] for c in old_centers}
    for p in patches:
        c = round(p.get_x() + p.get_width() / 2, 6)
        grouped[c].append(p)

    # for each category group, compute offsets relative to center
    for old_center, plist in grouped.items():
        if old_center not in old_map:
            continue
        cat = old_map[old_center]
        if cat not in cat_pos:
            continue
        new_center = cat_pos[cat]

        for p in plist:
            # center of this patch
            patch_center = p.get_x() + p.get_width() / 2
            offset = patch_center - old_center  # hue offset
            new_patch_center = new_center + offset
            p.set_x(new_patch_center - p.get_width() / 2)


def set_sharedx(axes):
    all_categories = []
    for ax in axes:
        labels = [tick.get_text() for tick in ax.get_xticklabels()]
        all_categories.extend(labels)

    # remove duplicates but keep order
    all_categories = list(dict.fromkeys(all_categories))

    for ax in axes:
        # remap_bars(ax, cat_pos)
        ax.set_xlim(-0.5, len(all_categories)-0.5)
        ax.set_xticks(range(len(all_categories)))
        ax.set_xticklabels(all_categories)

    #     ax.set_xlim(-0.5, len(all_categories)-0.5)
    #     ax.set_xticks(range(len(all_categories)))
    #     ax.set_xticklabels(all_categories)

    # # gather categories across all plots
    # all_categories = sorted({
    #     tick.get_text() 
    #     for ax in axes for tick in ax.get_xticklabels()
    # })

    # # cat_pos = {cat: i for i, cat in enumerate(all_categories)}

    # for ax in axes:
    #     ax.xaxis.set_major_locator(FixedLocator(range(len(all_categories))))
    #     ax.set_xticklabels(all_categories)
    #     ax.set_xlim(-0.5, len(all_categories) - 0.5)

def set_sharedy(axes:list):
    y_lims = [ax.get_ylim() for ax in axes]

    y_lim_min = min([y_lim[0] for y_lim in y_lims])
    y_lim_max = max([y_lim[1] for y_lim in y_lims])

    for ax in axes:
        ax.set_ylim((y_lim_min, y_lim_max))

def plot_grid(
        plots:list,
        nrows:int=2,
        ncols:int=2,
        figsize:tuple[int,int]=(12, 10),
        sharex:bool=False,
        sharey:bool=False,
        suptitle:str=None,
        wspace:float=None,
        hspace:float=None,
        projection:str|list='rectilinear'
    ):

    fig = plt.figure(figsize=figsize)
    gs = GridSpec(nrows, ncols, figure=fig, wspace=wspace, hspace=hspace)
    axes = []

    for i, plot in enumerate(plots):
        row, col = divmod(i, ncols)
        if isinstance(projection, list):
            ax = fig.add_subplot(gs[row, col], projection=projection[i])
        else:
            ax = fig.add_subplot(gs[row, col], projection=projection)
        axes.append(ax)
        plot(ax)
    
    if sharex:
        set_sharedx(axes)

    if sharey:
        set_sharedy(axes)

    if suptitle:
        if isinstance(suptitle, dict):
            fig.suptitle(suptitle.pop('t'), **suptitle)
        else:
            fig.suptitle(suptitle, fontsize=16)

    return fig, axes

def add_datapoints(
        ax:Axes,
        hue_order:list,
        repcalc_dir:str,
        groups:list,
        processing_stage:str,
        call_type:str='v_call',
        level:str='gene',
        mode:str='proportion',
        productive:bool=True,
        threshold:float=None,
        categories:list[str]=None
    ):
    dfs = []
    for group in groups:
        for rep_id in group[2]:
            df_points = br.load_gene_usage_data(
                repcalc_dir=repcalc_dir,
                repertoire_id=rep_id,
                processing_stage=processing_stage,
                call_type=call_type,
                level=level,
                mode=mode,
                productive=productive
            )
            df_points['condition'] = [group[1]]*df_points.shape[0]
            dfs.append(df_points)

    df_points = pd.concat(dfs)

    ## will keep the group if at least one value in 'gene' is not 0
    # if threshold is not None and isinstance(threshold, float):
    #     df_points.loc[:, 'duplicate_frequency'] = df_points['duplicate_frequency'].where(df_points['duplicate_frequency'] >= threshold, 0)
    #     df_points = df_points.groupby('gene').filter(lambda g: not (g['duplicate_frequency'] == 0).all())
    
    # will drop the group if all values of 'gene' in group are below threshold
    if threshold is not None and isinstance(threshold, float):
        df_points = df_points.groupby('gene').filter(
            lambda g: (g['duplicate_frequency'] >= threshold).any()
        )
    
    if categories:
        df_points = df_points[df_points['gene'].isin(categories)]

    # why does hue order not work?
    sns.stripplot(
        df_points,
        x='gene',
        y='duplicate_frequency',
        hue='condition',
        dodge=True,
        palette=['k']*len(hue_order),
        ax=ax,
        alpha=0.6,
        hue_order=hue_order,
        legend=False
    )

# for heatmaps
def norm_cols(matrix, norm_type='difference'):
    control_values = matrix.iloc[0, :]  # take first column as control
    if norm_type == 'fc':
        return (matrix.sub(control_values, axis=1)).div(control_values, axis=1)
    if norm_type == 'l2fc':
        return np.log2(matrix.div(control_values, axis=1)) # log2fc
    if norm_type == 'difference':
        return matrix.sub(control_values, axis=1)
    return matrix

# for heatmaps
def make_annotation_mat(matrix, standardized_matrix, round_mat=2, round_std_mat=2):
    # Now round and convert to string
    return matrix.round(round_mat).astype(str) + '\n(' + standardized_matrix.round(round_std_mat).astype(str) +')'


def generate_colormap(base_colors, all_names=None, n_shades=7, min_light=0, max_light=0.7):
    """
    Generate a dictionary of colors where each base color has n_shades variants
    going from dark to light, excluding white.

    Parameters
    ----------
    base_colors : dict
        Mapping of base condition name to base color (e.g., {'A': 'red', 'B': 'blue'}).
    n_shades : int
        Number of shades per base color.
    min_light : float
        Minimum lightness factor (0 = black, 1 = white).
    max_light : float
        Maximum lightness factor (0 = black, 1 = white).

    Returns
    -------
    dict : {condition_name: hex_color}
    """
    cmap_dict = {}

    for i, base in enumerate(base_colors):
        base_rgb = np.array(mcolors.to_rgb(base))
        for ii, factor in enumerate(np.linspace(min_light, max_light, n_shades)):
            # base_rgb * (1-factor) -> responsible for color being removed
            # np.ones(3) * factor -> responsible for the color interpolating to white
            shade_rgb = base_rgb * (1-factor) + (np.ones(3) * factor)
            
            cmap_dict[f"{all_names[i*n_shades+ii]}"] = mcolors.to_hex(shade_rgb)

    return cmap_dict

def show_colormap(color_cmap, ax=None, xtick_labels=True, xtick_height=-0.3):
    """
    Display colors associated in a color_cmap dictionary.

    Parameters
    ----------
    color_cmap : dict
        Dictionary mapping labels to color values (e.g., {'A': 'red', 'B': '#00FF00'}).
    """
    labels = list(color_cmap.keys())
    colors = list(color_cmap.values())

    # Create a figure
    if ax is None:
        fig, ax = plt.subplots(figsize=(len(labels), 1))
    else:
        fig = ax.get_figure()

    for i, color in enumerate(colors):
        ax.add_patch(plt.Rectangle((i, 0), 1, 1, color=color))
        if xtick_labels: ax.text(i + 0.5, xtick_height, labels[i], ha='center', va='center', fontsize=10, rotation=90)

    ax.set_xlim(0, len(colors))
    ax.set_ylim(0, 1)
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.set_xticks([])
    ax.set_yticks([])

    return fig, ax

# %% [markdown]
# ## Setup Directories/Read in Data

# %%
# Define project/job uuid
project_id = 'c0aef9ef-362d-46fd-abba-39ac0945bd66' # project uuid
job_id = 'ee73a6fb-fc35-4eed-86c5-5adbebb97cf8-007' # jov uuid

# Define data directories
data_dir = '/mnt/md0/Projects/MonsonLab/COVVAX/' #/path/to/data/directory/
repcalc_dir = data_dir + 'vdjserver/'+job_id+'/'
analysis_dir = data_dir + 'analysis/'
fig_dir = analysis_dir + 'figures/'

# Read in repertoire and repertoire group info
# The default name (repertoires.airr.json) is being used, but custom airr.json files can
# be used for defining repertoires and repertoire groups. 
# repertoires_airr_json_filename = 'cat3-7groups_with_RF.airr.json'
repertoires_airr_json_filename = 'repertoires.airr.json'
sample_info_df = br.read_repertoire_info_airr(repcalc_dir + repertoires_airr_json_filename)
repertoire_group_df = br.read_repertoire_group_info_airr(repcalc_dir + repertoires_airr_json_filename)
data = airr.read_airr(repcalc_dir + repertoires_airr_json_filename)

# pull out repertoires and names
repertoire_groups = { obj['repertoire_group_id'] : obj for obj in data['RepertoireGroup'] }
repertoires = { obj['repertoire_id'] : obj for obj in data['Repertoire']}

# make groups tuple
groups_tuple = [
    (
        repertoire_groups[rep_group_id]['repertoire_group_id'],
        repertoire_groups[rep_group_id]['repertoire_group_name'],
        [reps.get('repertoire_id') for reps in repertoire_groups[rep_group_id]['repertoires']]
    ) for rep_group_id in repertoire_groups
]

# identify control group to compare against
control_group_name = 'Low Neutralization'

for i, rep_group_id in enumerate(repertoire_groups):
    print(rep_group_id, i, repertoire_groups[rep_group_id]['repertoire_group_name'])
# Out:
# Total Number of Repertoire Groups:  56
# f805af34-f145-46b1-be17-a3634571fe3a 0 Healthy Control High Neutralization Cat 3-7
# 1c2d1b19-ca3f-4adb-befd-4bb87b1fa225 1 Healthy Control High Neutralization Cat 3-7 RF14
# e7792e03-5f92-450c-b393-53caa8428fdb 2 Healthy Control High Neutralization Cat 3-7 RF15
# 15dbf5f8-8b3d-4d2f-a052-6cc32a24827b 3 Healthy Control High Neutralization Cat 3-7 RF18
# 413e04e1-2ea5-4f61-8cef-c1bea3f151e2 4 Healthy Control High Neutralization Cat 3-7 RF19
# a32d709b-b3ed-43da-b962-4f06ad2d63e5 5 Healthy Control High Neutralization Cat 3-7 RF22
# c303fd0a-366a-4b0a-976c-b7ac524d1038 6 Healthy Control High Neutralization Cat 3-7 RF23
# 79b0fa11-e8ee-4628-b00b-ae5b85a88c0a 7 Heme Cancer High Neutralization Cat 3-7
# f84a9644-5765-4d16-83b8-f62c6bfca4c9 8 Heme Cancer High Neutralization Cat 3-7 RF14
# a3805571-069b-4034-b317-27f757dc4fd3 9 Heme Cancer High Neutralization Cat 3-7 RF15
# 997b2d8b-9195-4358-bfb5-65da65bcc127 10 Heme Cancer High Neutralization Cat 3-7 RF18
# 2b8e547b-83e8-4f3c-99df-3fc2af4abca1 11 Heme Cancer High Neutralization Cat 3-7 RF19
# 63ece112-23ee-47f1-a656-722826e6158e 12 Heme Cancer High Neutralization Cat 3-7 RF22
# 07125730-6e94-4cc9-a89a-2bb2b7c16a6d 13 Heme Cancer High Neutralization Cat 3-7 RF23
# 167ecf28-c395-40ed-9651-a7ef7d0784cb 14 Low Neutralization
# adc41594-38fa-4ca1-a895-cc9275341583 15 Low Neutralization RF14
# a0e6a60c-81e6-4364-a8d8-327ce72ac477 16 Low Neutralization RF15
# 8f7ed9f8-aad1-498a-8980-2f621e067cf9 17 Low Neutralization RF18
# 7b15c4b7-c1df-4c48-80e1-83b99fcedd8a 18 Low Neutralization RF19
# a404ef11-fc7b-4eac-802a-5cd9f2d5d272 19 Low Neutralization RF22
# 2dad0b13-a160-4308-9303-f61daec88b8d 20 Low Neutralization RF23
# 2cc30562-7072-483d-96aa-0239b3cc8bca 21 Neuroimmunology High Neutralization Cat 3-7
# 3560b1a9-9e9c-4186-8319-84c0313b769b 22 Neuroimmunology High Neutralization Cat 3-7 RF14
# 8cbd8e31-dffc-4d85-a309-75e8da5a477a 23 Neuroimmunology High Neutralization Cat 3-7 RF15
# 5c684971-6b8e-4c2c-b499-02b51df6842f 24 Neuroimmunology High Neutralization Cat 3-7 RF18
# 1da121a2-94b7-45f8-af3d-8e5e136f0af4 25 Neuroimmunology High Neutralization Cat 3-7 RF19
# 06246756-d9c7-4b1e-bff8-c24ec3a6849e 26 Neuroimmunology High Neutralization Cat 3-7 RF22
# 91727c4c-8666-4306-a48a-8130bf570be0 27 Neuroimmunology High Neutralization Cat 3-7 RF23
# 8d6e4f6b-4136-4703-b114-27df33fc1ca8 28 Solid Cancer High Neutralization Cat 3-7
# 350a398e-7fd8-4c14-8287-03880daebcb0 29 Solid Cancer High Neutralization Cat 3-7 RF14
# babce6f4-4c85-48b4-a9e8-cf733aeba54c 30 Solid Cancer High Neutralization Cat 3-7 RF15
# be5f0961-4592-4a73-a2bb-cf03eaf28971 31 Solid Cancer High Neutralization Cat 3-7 RF18
# 1e255ccf-7ca6-4917-81bc-c477731a5e00 32 Solid Cancer High Neutralization Cat 3-7 RF19
# fd6060e1-38ec-4b10-af0a-93fbaccf95ff 33 Solid Cancer High Neutralization Cat 3-7 RF22
# 8449bdd5-39d3-4cb1-88f4-a37e0041acec 34 Solid Cancer High Neutralization Cat 3-7 RF23
# ad5489b5-6cff-4773-bb76-ec09b2573ff3 35 Cat. 1 High Neutralization
# 08475c9e-efb6-4302-8bb1-77186b5b86b9 36 Cat. 1 Low Neutralization
# a57c907d-39aa-407c-99df-9c105d43407d 37 Cat. 2-7 High Neutralization
# 540bc5f1-2a71-4dbc-833f-e01e562e7e03 38 Cat. 2-7 Low Neutralization
# 1672807c-ba98-4ec4-aa96-e2023c4dd23a 39 Cat. 4-5 High Neutralization
# fece9f9e-b20e-4df2-bd24-fc4e8cc213d3 40 Cat. 6 High Neutralization
# 2abdc4e5-dd79-4c39-b7b9-b4e8ee642ec1 41 Cat. 6 Low Neutralization
# 3621f37f-2b34-478b-af42-ef1fb1f7e799 42 Cat. 7 High Neutralization
# 523b4d12-eb73-4a29-bbdd-ebe17576554f 43 Healthy Control
# 3357bc71-0423-495e-9745-b159398e84ec 44 Healthy Control High Neutralization
# 67e77903-4ee3-4e54-9690-acf4a316a7a4 45 Healthy Control Low Neutralization
# 8a1cd1bd-9279-4cb7-883a-1b8ad7f0764f 46 Heme Cancer
# fa463db5-ed68-4d31-8618-90b12143c7f5 47 Heme Cancer High Neutralization
# 8e179bce-73ba-4f3f-92b7-5076aeea02a3 48 Heme Cancer Low Neutralization
# b08f9f20-8770-42e2-a785-ff9443b6edb6 49 High Neutralization
# d262632b-51d7-49f9-9505-d7ac839f6938 50 Neuroimmunology
# bf73e138-0ac8-4a80-b6ac-bb8b1461d212 51 Neuroimmunology High Neutralization
# 2e3b2bc3-885c-4a8d-8f0a-f5924a9a9f4a 52 Neuroimmunology Low Neutralizatoin
# ffb943d1-7afa-484d-88f2-3dd2efc0b102 53 Solid Cancer
# 5bdeb2de-e95f-4fb0-94ee-6ef9c319ddb4 54 Solid Cancer High Neutralization
# 66b5eec4-8411-456e-b02a-c0a380ba6a13 55 Solid Cancer Low Neutralization

# %% [markdown]
# ## Colormaps

# %%
cmap = mpl.colormaps['nipy_spectral'] # gist_rainbow
cmin = 0.0
cmax = 1.0

# V
v_genes = br.load_gene_usage_group_data(
    repcalc_dir=repcalc_dir,
    groups=groups_tuple,
    processing_stage='igblast.makedb.gene.clone',
    call_type='v_call',
    level='gene'
)['gene'].unique()
v_genes_cmap = {
    v_gene : cmap(np.linspace(cmin,cmax,len(v_genes))[i])
    for i, v_gene in enumerate(v_genes)
}

v_subgroups = br.load_gene_usage_group_data(
    repcalc_dir=repcalc_dir,
    groups=groups_tuple,
    processing_stage='igblast.makedb.gene.clone',
    call_type='v_call',
    level='subgroup'
)['gene'].unique()
v_subgroup_cmap = {
    v_subgroup : cmap(np.linspace(cmin,cmax,len(v_subgroups))[i])
    for i, v_subgroup in enumerate(v_subgroups)
}

# J
j_genes = br.load_gene_usage_group_data(
    repcalc_dir=repcalc_dir,
    groups=groups_tuple,
    processing_stage='igblast.makedb.gene.clone',
    call_type='j_call',
    level='gene'
)['gene'].unique()
j_genes_cmap = {
    j_gene : cmap(np.linspace(cmin,cmax,len(j_genes))[i])
    for i, j_gene in enumerate(j_genes)
}

j_subgroups = br.load_gene_usage_group_data(
    repcalc_dir=repcalc_dir,
    groups=groups_tuple,
    processing_stage='igblast.makedb.gene.clone',
    call_type='j_call',
    level='subgroup'
)['gene'].unique()
j_subgroup_cmap = {
    j_subgroup : cmap(np.linspace(cmin,cmax,len(j_subgroups))[i])
    for i, j_subgroup in enumerate(j_subgroups)
}

## cond_cmap
conds = br.load_and_prepare_data_junction_aa(
    repcalc_dir=repcalc_dir,
    groups=groups_tuple,
    processing_stage='.igblast.makedb.allele.clone.group.',
    call_type='junction_aa_length'
)['condition'].unique()


conds.sort()

cond_cmap = {
    cond : cmap(np.linspace(0.1,0.98,len(conds))[i])
    for i, cond in enumerate(conds)
}

# set hue order (use condition names)
hue_order = [
    'Low Neutralization', 'Healthy Control High Neutralization Cat 3-7', 'Heme Cancer High Neutralization Cat 3-7', 'Solid Cancer High Neutralization Cat 3-7', 'Neuroimmunology High Neutralization Cat 3-7'
]

# Colorblind safe colors and colorblind analysis
# number of colors = number of base groups to compare
base_colors = ['#A577F9', '#699B59', '#D36135', '#086788', '#FFBC42']
names = [cond[1] for cond in groups_tuple]
names.sort()
cond_cmap = generate_colormap(base_colors, names, n_shades=7, min_light=0.1, max_light=0.7)
cond_cmap_solid = generate_colormap(base_colors, names, n_shades=7, min_light=0.1, max_light=0.1)

deuteranomaly_simulated_cmap = cs.cspace_convert(
    [mcolors.to_rgb(e) for e in cond_cmap.values()], 
    start = {
        "name": "sRGB1+CVD",
        "cvd_type": "deuteranomaly",
        "severity": 100
    },
    end = "sRGB1"
)

protanomaly_simulated_cmap = cs.cspace_convert(
    [mcolors.to_rgb(e) for e in cond_cmap.values()], 
    start = {
        "name": "sRGB1+CVD",
        "cvd_type": "protanomaly",
        "severity": 100
    },
    end = "sRGB1"
)

tritanomaly_simulated_cmap = cs.cspace_convert(
    [mcolors.to_rgb(e) for e in cond_cmap.values()], 
    start = {
        "name": "sRGB1+CVD",
        "cvd_type": "tritanomaly",
        "severity": 100
    },
    end = "sRGB1"
)

fig, axes = plt.subplots(4, 1, figsize=(len(list(cond_cmap.keys())), 4))
colorblind_simulated_cmaps = [deuteranomaly_simulated_cmap, protanomaly_simulated_cmap, tritanomaly_simulated_cmap]
show_colormap(cond_cmap, axes[0], False)
for i, (ax, colorblind_simulated_cmap) in enumerate(zip(axes[1:], colorblind_simulated_cmaps)):
    colorblind_simulated_cmap = [np.clip(e, 0, 1) for e in colorblind_simulated_cmap]
    colorblind_simulated_cmap = {k:v for k,v in zip(cond_cmap.keys(), colorblind_simulated_cmap)}
    if i != 2: show_colormap(colorblind_simulated_cmap, ax, False)
    else: show_colormap(colorblind_simulated_cmap, ax, True, 2.5)

axes[0].set_ylabel('Normal', rotation=0, labelpad=20)
axes[1].set_ylabel('Deuteranomaly', rotation=0, labelpad=39)
axes[2].set_ylabel('Protanomaly', rotation=0, labelpad=32)
axes[3].set_ylabel('Tritanomaly', rotation=0, labelpad=32)
fig.suptitle('Colorblind Analysis', fontsize=24, y=1.02)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 6
#       3 cmax = 1.0
#       5 # V
# ----> 6 v_genes = br.load_gene_usage_group_data(
#       7     repcalc_dir=repcalc_dir,
#       8     groups=groups_tuple,
#       9     processing_stage='igblast.makedb.gene.clone',
#      10     call_type='v_call',
#      11     level='gene'
#      12 )['gene'].unique()
#      13 v_genes_cmap = {
#      14     v_gene : cmap(np.linspace(cmin,cmax,len(v_genes))[i])
#      15     for i, v_gene in enumerate(v_genes)
#      16 }
#      18 v_subgroups = br.load_gene_usage_group_data(
#      19     repcalc_dir=repcalc_dir,
#      20     groups=groups_tuple,
#    (...)     23     level='subgroup'
#      24 )['gene'].unique()
#
# File /mnt/md0/s236922/cowell-lab/repertoire_zoo/repertoire_zoo/bird.py:198, in load_gene_usage_group_data(repcalc_dir, groups, processing_stage, call_type, level, mode, productive, threshold, datapoints, categories)
#     196 for group_id, condition_name, *_ in groups:
#     197     path = f"{repcalc_dir}{group_id}.{processing_stage}.group.{call_type}.tsv"
# --> 198     df = pd.read_csv(path, sep='\t')
#     199     df = df[(df['level']==level) & (df['mode']==mode) & (df['productive']==productive)]
#     200     df = df.loc[:,['gene', 'duplicate_frequency_avg', 'duplicate_frequency_std', 'N']]
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/md0/Projects/MonsonLab/COVVAX/vdjserver/ee73a6fb-fc35-4eed-86c5-5adbebb97cf8-007/f805af34-f145-46b1-be17-a3634571fe3a.igblast.makedb.gene.clone.group.v_call.tsv'

# %% [markdown]
# # V

# %% [markdown]
# ## Bar graphs of VH Family usage

# %%
global threshold, ylim, processing_stage, call_type, level
threshold = 0.001 #0.02
ylim = (0,1)
processing_stage = 'igblast.makedb.gene.clone'
call_type = 'v_call'
level = 'subgroup'

df = br.load_gene_usage_group_data(
    repcalc_dir=repcalc_dir,
    groups=groups_tuple,
    processing_stage=processing_stage,
    call_type=call_type,
    level=level,
    threshold=threshold
)

fig, ax = gr.plot_duplicate_frequency(
    df=df[df['condition'].isin(hue_order)],
    hue_order=hue_order,
    palette=cond_cmap,
    # title={'t':'(A)', 'x':0, 'fontsize':16, 'weight':'bold'},
    ylim=ylim,
    errorbar='se',
    split=True,
    legend=True
)

add_datapoints(
    ax,
    hue_order,
    repcalc_dir=repcalc_dir,
    groups=groups_tuple[0:5],
    processing_stage=processing_stage,
    call_type=call_type,
    level=level,
    threshold=threshold,
    categories=list(df['gene'].unique())
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 8
#       5 call_type = 'v_call'
#       6 level = 'subgroup'
# ----> 8 df = br.load_gene_usage_group_data(
#       9     repcalc_dir=repcalc_dir,
#      10     groups=groups_tuple,
#      11     processing_stage=processing_stage,
#      12     call_type=call_type,
#      13     level=level,
#      14     threshold=threshold
#      15 )
#      17 fig, ax = gr.plot_duplicate_frequency(
#      18     df=df[df['condition'].isin(hue_order)],
#      19     hue_order=hue_order,
#    (...)     25     legend=True
#      26 )
#      28 add_datapoints(
#      29     ax,
#      30     hue_order,
#    (...)     37     categories=list(df['gene'].unique())
#      38 )
#
# File /mnt/md0/s236922/cowell-lab/repertoire_zoo/repertoire_zoo/bird.py:198, in load_gene_usage_group_data(repcalc_dir, groups, processing_stage, call_type, level, mode, productive, threshold, datapoints, categories)
#     196 for group_id, condition_name, *_ in groups:
#     197     path = f"{repcalc_dir}{group_id}.{processing_stage}.group.{call_type}.tsv"
# --> 198     df = pd.read_csv(path, sep='\t')
#     199     df = df[(df['level']==level) & (df['mode']==mode) & (df['productive']==productive)]
#     200     df = df.loc[:,['gene', 'duplicate_frequency_avg', 'duplicate_frequency_std', 'N']]
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/md0/Projects/MonsonLab/COVVAX/vdjserver/ee73a6fb-fc35-4eed-86c5-5adbebb97cf8-007/f805af34-f145-46b1-be17-a3634571fe3a.igblast.makedb.gene.clone.group.v_call.tsv'

# %% [markdown]
# ## Heat maps

# %% [markdown]
# #### Raw Data

# %%
global threshold, ylim, processing_stage, call_type, level
threshold = 0.001 #0.02
ylim = (0,1)
processing_stage = 'igblast.makedb.gene.clone'
call_type = 'v_call'
level = 'subgroup'

df = br.load_gene_usage_group_data(
        repcalc_dir=repcalc_dir,
        groups=groups_tuple,
        processing_stage=processing_stage,
        call_type=call_type,
        level=level,
        threshold=threshold
    )

idx = list(df['condition'].unique())
# idx = [idx[2]]+idx[0:2]+idx[3:] # rearange for order

matrix = df.pivot(
    index="condition",
    columns="gene",
    values="duplicate_frequency_avg"
).reindex(idx)

# make figure
n_rows, n_cols = matrix.shape
fig, ax = plt.subplots(figsize=(1.4*n_cols, 0.5*n_rows+1))
sns.heatmap(matrix, ax=ax, annot=True)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 8
#       5 call_type = 'v_call'
#       6 level = 'subgroup'
# ----> 8 df = br.load_gene_usage_group_data(
#       9         repcalc_dir=repcalc_dir,
#      10         groups=groups_tuple,
#      11         processing_stage=processing_stage,
#      12         call_type=call_type,
#      13         level=level,
#      14         threshold=threshold
#      15     )
#      17 idx = list(df['condition'].unique())
#      18 # idx = [idx[2]]+idx[0:2]+idx[3:] # rearange for order
#
# File /mnt/md0/s236922/cowell-lab/repertoire_zoo/repertoire_zoo/bird.py:198, in load_gene_usage_group_data(repcalc_dir, groups, processing_stage, call_type, level, mode, productive, threshold, datapoints, categories)
#     196 for group_id, condition_name, *_ in groups:
#     197     path = f"{repcalc_dir}{group_id}.{processing_stage}.group.{call_type}.tsv"
# --> 198     df = pd.read_csv(path, sep='\t')
#     199     df = df[(df['level']==level) & (df['mode']==mode) & (df['productive']==productive)]
#     200     df = df.loc[:,['gene', 'duplicate_frequency_avg', 'duplicate_frequency_std', 'N']]
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/md0/Projects/MonsonLab/COVVAX/vdjserver/ee73a6fb-fc35-4eed-86c5-5adbebb97cf8-007/f805af34-f145-46b1-be17-a3634571fe3a.igblast.makedb.gene.clone.group.v_call.tsv'

# %% [markdown]
# #### Absolute Difference per Gene Family (Unpaired Axis)

# %%
global threshold, ylim, processing_stage, call_type, level
threshold = 0.001 #0.02
ylim = (0,1)
processing_stage = 'igblast.makedb.gene.clone'
call_type = 'v_call'
level = 'subgroup'

df = br.load_gene_usage_group_data(
        repcalc_dir=repcalc_dir,
        groups=groups_tuple,
        processing_stage=processing_stage,
        call_type=call_type,
        level=level,
        threshold=threshold
    )

idx = list(df['condition'].unique())
# idx = [idx[2]]+idx[0:2]+idx[3:] # rearange for order

matrix = df.pivot(
    index="condition",
    columns="gene",
    values="duplicate_frequency_avg"
).reindex(idx)

# make sure matrix is numeric
matrix = matrix.astype(float)

cmaps = []
ims = []
norms = []
n_rows, n_cols = matrix.shape
fig, ax = plt.subplots(figsize=(1.4*n_cols, 0.5*n_rows+1))

for j, col in enumerate(matrix.columns):
    vals = matrix[col].values  # shape (n_rows,)

    # set up colormap and norm
    cmap = LinearSegmentedColormap.from_list(col, ['Blue', 'White', 'Red'])
    cmaps.append(cmap)
    v_min = vals.min()
    v_center = vals[0]
    v_max = vals.max()
    # add jitter so that center value does not equal min or max for colormap
    if v_min == v_center:
        v_min -= 0.0000001
    if v_max == v_center:
        v_max += 0.0000001
    norm = mpl.colors.TwoSlopeNorm(vmin=v_min, vcenter=v_center, vmax=v_max)
    norms.append(norm)


    # draw the column as an image of shape (n_rows, 1)
    im = ax.imshow(vals[:, None], cmap=cmap, norm=norm, aspect='auto',
                extent=[j, j+1, 0, n_rows], origin='lower')
    ims.append(im)

    # add text annotations
    for k, v in enumerate(vals):
        ax.text(j + 0.5, k + 0.5, f"{v:.5f}", ha='center', va='center', fontsize=8, color='k')

# ticks and limits
ax.set_xticks(np.arange(n_cols) + 0.5)
ax.set_xticklabels(matrix.columns, rotation=90, y=-0.025)
ax.set_yticks(np.arange(n_rows) + 0.5)
ax.set_yticklabels(matrix.index)
ax.set_xlim(0, n_cols)
ax.set_ylim(0, n_rows)

# add legend below each column
for j, (cmap, norm) in enumerate(zip(cmaps, norms)):
    cax = inset_axes(ax, width="80%", height="25%", loc="lower center",
                    bbox_to_anchor=(j, -0.45, 1, 1),  # shift horizontally
                    bbox_transform=ax.transData, borderpad=0)
    fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap),
                cax=cax, orientation="horizontal")
    cax.xaxis.set_ticks_position("bottom")   
    cax.xaxis.set_tick_params(labelrotation=45, labelsize=6)   

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 8
#       5 call_type = 'v_call'
#       6 level = 'subgroup'
# ----> 8 df = br.load_gene_usage_group_data(
#       9         repcalc_dir=repcalc_dir,
#      10         groups=groups_tuple,
#      11         processing_stage=processing_stage,
#      12         call_type=call_type,
#      13         level=level,
#      14         threshold=threshold
#      15     )
#      17 idx = list(df['condition'].unique())
#      18 # idx = [idx[2]]+idx[0:2]+idx[3:] # rearange for order
#
# File /mnt/md0/s236922/cowell-lab/repertoire_zoo/repertoire_zoo/bird.py:198, in load_gene_usage_group_data(repcalc_dir, groups, processing_stage, call_type, level, mode, productive, threshold, datapoints, categories)
#     196 for group_id, condition_name, *_ in groups:
#     197     path = f"{repcalc_dir}{group_id}.{processing_stage}.group.{call_type}.tsv"
# --> 198     df = pd.read_csv(path, sep='\t')
#     199     df = df[(df['level']==level) & (df['mode']==mode) & (df['productive']==productive)]
#     200     df = df.loc[:,['gene', 'duplicate_frequency_avg', 'duplicate_frequency_std', 'N']]
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/md0/Projects/MonsonLab/COVVAX/vdjserver/ee73a6fb-fc35-4eed-86c5-5adbebb97cf8-007/f805af34-f145-46b1-be17-a3634571fe3a.igblast.makedb.gene.clone.group.v_call.tsv'

# %% [markdown]
# #### Normalized Difference

# %%
global threshold, ylim, processing_stage, call_type, level
threshold = 0.001 #0.02
ylim = (0,1)
processing_stage = 'igblast.makedb.gene.clone'
call_type = 'v_call'
level = 'subgroup'

df = br.load_gene_usage_group_data(
        repcalc_dir=repcalc_dir,
        groups=groups_tuple,
        processing_stage=processing_stage,
        call_type=call_type,
        level=level,
        threshold=threshold
    )

idx = list(df['condition'].unique())
# idx = [idx[2]]+idx[0:2]+idx[3:] # rearange for order

matrix = df.pivot(
    index="condition",
    columns="gene",
    values="duplicate_frequency_avg"
).reindex(idx)

# make sure matrix is numeric
matrix = matrix.astype(float)

# make normalized matrix
norm_mat = norm_cols(matrix, 'difference')

# make annotation matrix
annot_mat = make_annotation_mat(matrix, norm_mat, 4, 4)

# make figure
n_rows, n_cols = matrix.shape
fig, ax = plt.subplots(figsize=(1.4*n_cols, 0.5*n_rows+1))

sns.heatmap(
    norm_mat,
    annot=annot_mat,
    fmt='',
    cmap="RdBu_r",
    vmin=-0.11,
    vmax=0.11,
    ax=ax
)

ax.set_title(
    'Difference Between Repertoire Group and Control by Gene Family',
    fontdict={'fontsize':20},
    x=(1.2-0.4)/2
)
ax.set_ylabel('Repertoire Group')
ax.set_xlabel('Gene Family')

fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 8
#       5 call_type = 'v_call'
#       6 level = 'subgroup'
# ----> 8 df = br.load_gene_usage_group_data(
#       9         repcalc_dir=repcalc_dir,
#      10         groups=groups_tuple,
#      11         processing_stage=processing_stage,
#      12         call_type=call_type,
#      13         level=level,
#      14         threshold=threshold
#      15     )
#      17 idx = list(df['condition'].unique())
#      18 # idx = [idx[2]]+idx[0:2]+idx[3:] # rearange for order
#
# File /mnt/md0/s236922/cowell-lab/repertoire_zoo/repertoire_zoo/bird.py:198, in load_gene_usage_group_data(repcalc_dir, groups, processing_stage, call_type, level, mode, productive, threshold, datapoints, categories)
#     196 for group_id, condition_name, *_ in groups:
#     197     path = f"{repcalc_dir}{group_id}.{processing_stage}.group.{call_type}.tsv"
# --> 198     df = pd.read_csv(path, sep='\t')
#     199     df = df[(df['level']==level) & (df['mode']==mode) & (df['productive']==productive)]
#     200     df = df.loc[:,['gene', 'duplicate_frequency_avg', 'duplicate_frequency_std', 'N']]
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/md0/Projects/MonsonLab/COVVAX/vdjserver/ee73a6fb-fc35-4eed-86c5-5adbebb97cf8-007/f805af34-f145-46b1-be17-a3634571fe3a.igblast.makedb.gene.clone.group.v_call.tsv'

# %% [markdown]
# # J

# %% [markdown]
# ## Bar graph

# %%
global threshold, ylim, processing_stage, call_type, level
threshold = 0.001 #0.02
ylim = (0,1)
processing_stage = 'igblast.makedb.gene.clone'
call_type = 'j_call'
level = 'subgroup'

df = br.load_gene_usage_group_data(
    repcalc_dir=repcalc_dir,
    groups=groups_tuple,
    processing_stage=processing_stage,
    call_type=call_type,
    level=level,
    threshold=threshold
)

fig, ax = gr.plot_duplicate_frequency(
    df=df[df['condition'].isin(hue_order)],
    hue_order=hue_order,
    palette=cond_cmap,
    # title={'t':'(A)', 'x':0, 'fontsize':16, 'weight':'bold'},
    ylim=ylim,
    errorbar='se',
    split=True,
    legend=True
)

add_datapoints(
    ax,
    hue_order,
    repcalc_dir=repcalc_dir,
    groups=groups_tuple,
    processing_stage=processing_stage,
    call_type=call_type,
    level=level,
    threshold=threshold,
    categories=list(df['gene'].unique())
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 8
#       5 call_type = 'j_call'
#       6 level = 'subgroup'
# ----> 8 df = br.load_gene_usage_group_data(
#       9     repcalc_dir=repcalc_dir,
#      10     groups=groups_tuple,
#      11     processing_stage=processing_stage,
#      12     call_type=call_type,
#      13     level=level,
#      14     threshold=threshold
#      15 )
#      17 fig, ax = gr.plot_duplicate_frequency(
#      18     df=df[df['condition'].isin(hue_order)],
#      19     hue_order=hue_order,
#    (...)     25     legend=True
#      26 )
#      28 add_datapoints(
#      29     ax,
#      30     hue_order,
#    (...)     37     categories=list(df['gene'].unique())
#      38 )
#
# File /mnt/md0/s236922/cowell-lab/repertoire_zoo/repertoire_zoo/bird.py:198, in load_gene_usage_group_data(repcalc_dir, groups, processing_stage, call_type, level, mode, productive, threshold, datapoints, categories)
#     196 for group_id, condition_name, *_ in groups:
#     197     path = f"{repcalc_dir}{group_id}.{processing_stage}.group.{call_type}.tsv"
# --> 198     df = pd.read_csv(path, sep='\t')
#     199     df = df[(df['level']==level) & (df['mode']==mode) & (df['productive']==productive)]
#     200     df = df.loc[:,['gene', 'duplicate_frequency_avg', 'duplicate_frequency_std', 'N']]
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/md0/Projects/MonsonLab/COVVAX/vdjserver/ee73a6fb-fc35-4eed-86c5-5adbebb97cf8-007/f805af34-f145-46b1-be17-a3634571fe3a.igblast.makedb.gene.clone.group.j_call.tsv'

# %% [markdown]
# ## Heat maps

# %% [markdown]
# #### Raw Data

# %%
global threshold, ylim, processing_stage, call_type, level
threshold = 0.001 #0.02
ylim = (0,1)
processing_stage = 'igblast.makedb.gene.clone'
call_type = 'j_call'
level = 'subgroup'

df = br.load_gene_usage_group_data(
        repcalc_dir=repcalc_dir,
        groups=groups_tuple,
        processing_stage=processing_stage,
        call_type=call_type,
        level=level,
        threshold=threshold
    )

idx = list(df['condition'].unique())
# idx = [idx[2]]+idx[0:2]+idx[3:] # rearange for order

matrix = df.pivot(
    index="condition",
    columns="gene",
    values="duplicate_frequency_avg"
).reindex(idx)

# make figure
n_rows, n_cols = matrix.shape
fig, ax = plt.subplots(figsize=(1.4*n_cols, 0.5*n_rows+1))
sns.heatmap(matrix, ax=ax, annot=True)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 8
#       5 call_type = 'j_call'
#       6 level = 'subgroup'
# ----> 8 df = br.load_gene_usage_group_data(
#       9         repcalc_dir=repcalc_dir,
#      10         groups=groups_tuple,
#      11         processing_stage=processing_stage,
#      12         call_type=call_type,
#      13         level=level,
#      14         threshold=threshold
#      15     )
#      17 idx = list(df['condition'].unique())
#      18 # idx = [idx[2]]+idx[0:2]+idx[3:] # rearange for order
#
# File /mnt/md0/s236922/cowell-lab/repertoire_zoo/repertoire_zoo/bird.py:198, in load_gene_usage_group_data(repcalc_dir, groups, processing_stage, call_type, level, mode, productive, threshold, datapoints, categories)
#     196 for group_id, condition_name, *_ in groups:
#     197     path = f"{repcalc_dir}{group_id}.{processing_stage}.group.{call_type}.tsv"
# --> 198     df = pd.read_csv(path, sep='\t')
#     199     df = df[(df['level']==level) & (df['mode']==mode) & (df['productive']==productive)]
#     200     df = df.loc[:,['gene', 'duplicate_frequency_avg', 'duplicate_frequency_std', 'N']]
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/md0/Projects/MonsonLab/COVVAX/vdjserver/ee73a6fb-fc35-4eed-86c5-5adbebb97cf8-007/f805af34-f145-46b1-be17-a3634571fe3a.igblast.makedb.gene.clone.group.j_call.tsv'

# %% [markdown]
# #### Absolute Difference per Gene Family (Unpaired Axis)

# %%
global threshold, ylim, processing_stage, call_type, level
threshold = 0.001 #0.02
ylim = (0,1)
processing_stage = 'igblast.makedb.gene.clone'
call_type = 'j_call'
level = 'subgroup'

df = br.load_gene_usage_group_data(
        repcalc_dir=repcalc_dir,
        groups=groups_tuple,
        processing_stage=processing_stage,
        call_type=call_type,
        level=level,
        threshold=threshold
    )

idx = list(df['condition'].unique())
# idx = [idx[2]]+idx[0:2]+idx[3:] # rearange for order

matrix = df.pivot(
    index="condition",
    columns="gene",
    values="duplicate_frequency_avg"
).reindex(idx)

# make sure matrix is numeric
matrix = matrix.astype(float)

cmaps = []
ims = []
norms = []
n_rows, n_cols = matrix.shape
fig, ax = plt.subplots(figsize=(1.4*n_cols, 0.5*n_rows+1))

for j, col in enumerate(matrix.columns):
    vals = matrix[col].values  # shape (n_rows,)

    # set up colormap and norm
    cmap = LinearSegmentedColormap.from_list(col, ['Blue', 'White', 'Red'])
    cmaps.append(cmap)
    v_min = vals.min()
    v_center = vals[0]
    v_max = vals.max()
    # add jitter so that center value does not equal min or max for colormap
    if v_min == v_center:
        v_min -= 0.0000001
    if v_max == v_center:
        v_max += 0.0000001
    norm = mpl.colors.TwoSlopeNorm(vmin=v_min, vcenter=v_center, vmax=v_max)
    norms.append(norm)


    # draw the column as an image of shape (n_rows, 1)
    im = ax.imshow(vals[:, None], cmap=cmap, norm=norm, aspect='auto',
                extent=[j, j+1, 0, n_rows], origin='lower')
    ims.append(im)

    # add text annotations
    for k, v in enumerate(vals):
        ax.text(j + 0.5, k + 0.5, f"{v:.5f}", ha='center', va='center', fontsize=8, color='k')

# ticks and limits
ax.set_xticks(np.arange(n_cols) + 0.5)
ax.set_xticklabels(matrix.columns, rotation=90, y=-0.025)
ax.set_yticks(np.arange(n_rows) + 0.5)
ax.set_yticklabels(matrix.index)
ax.set_xlim(0, n_cols)
ax.set_ylim(0, n_rows)

# add legend below each column
for j, (cmap, norm) in enumerate(zip(cmaps, norms)):
    cax = inset_axes(ax, width="80%", height="25%", loc="lower center",
                    bbox_to_anchor=(j, -0.45, 1, 1),  # shift horizontally
                    bbox_transform=ax.transData, borderpad=0)
    fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap),
                cax=cax, orientation="horizontal")
    cax.xaxis.set_ticks_position("bottom")   
    cax.xaxis.set_tick_params(labelrotation=45, labelsize=6)   

# plt.tight_layout()
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 8
#       5 call_type = 'j_call'
#       6 level = 'subgroup'
# ----> 8 df = br.load_gene_usage_group_data(
#       9         repcalc_dir=repcalc_dir,
#      10         groups=groups_tuple,
#      11         processing_stage=processing_stage,
#      12         call_type=call_type,
#      13         level=level,
#      14         threshold=threshold
#      15     )
#      17 idx = list(df['condition'].unique())
#      18 # idx = [idx[2]]+idx[0:2]+idx[3:] # rearange for order
#
# File /mnt/md0/s236922/cowell-lab/repertoire_zoo/repertoire_zoo/bird.py:198, in load_gene_usage_group_data(repcalc_dir, groups, processing_stage, call_type, level, mode, productive, threshold, datapoints, categories)
#     196 for group_id, condition_name, *_ in groups:
#     197     path = f"{repcalc_dir}{group_id}.{processing_stage}.group.{call_type}.tsv"
# --> 198     df = pd.read_csv(path, sep='\t')
#     199     df = df[(df['level']==level) & (df['mode']==mode) & (df['productive']==productive)]
#     200     df = df.loc[:,['gene', 'duplicate_frequency_avg', 'duplicate_frequency_std', 'N']]
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/md0/Projects/MonsonLab/COVVAX/vdjserver/ee73a6fb-fc35-4eed-86c5-5adbebb97cf8-007/f805af34-f145-46b1-be17-a3634571fe3a.igblast.makedb.gene.clone.group.j_call.tsv'

# %% [markdown]
# #### Normalized Difference

# %%
global threshold, ylim, processing_stage, call_type, level
threshold = 0.001 #0.02
ylim = (0,1)
processing_stage = 'igblast.makedb.gene.clone'
call_type = 'j_call'
level = 'subgroup'

df = br.load_gene_usage_group_data(
        repcalc_dir=repcalc_dir,
        groups=groups_tuple,
        processing_stage=processing_stage,
        call_type=call_type,
        level=level,
        threshold=threshold
    )

idx = list(df['condition'].unique())
# idx = [idx[2]]+idx[0:2]+idx[3:] # rearange for order

matrix = df.pivot(
    index="condition",
    columns="gene",
    values="duplicate_frequency_avg"
).reindex(idx)

# make sure matrix is numeric
matrix = matrix.astype(float)

# make normalized matrix
norm_mat = norm_cols(matrix, 'difference')

# make annotation matrix
annot_mat = make_annotation_mat(matrix, norm_mat, 4, 4)

# make figure
n_rows, n_cols = matrix.shape
fig, ax = plt.subplots(figsize=(1.4*n_cols, 0.5*n_rows+1))

sns.heatmap(
    norm_mat,
    annot=annot_mat,
    fmt='',
    cmap="RdBu_r",
    vmin=-0.11,
    vmax=0.11,
    ax=ax
)

ax.set_title(
    'Difference Between Repertoire Group and Control by Gene Family',
    fontdict={'fontsize':20},
    x=(1.2-0.4)/2
)
ax.set_ylabel('Repertoire Group')
ax.set_xlabel('Gene Family')

fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 8
#       5 call_type = 'j_call'
#       6 level = 'subgroup'
# ----> 8 df = br.load_gene_usage_group_data(
#       9         repcalc_dir=repcalc_dir,
#      10         groups=groups_tuple,
#      11         processing_stage=processing_stage,
#      12         call_type=call_type,
#      13         level=level,
#      14         threshold=threshold
#      15     )
#      17 idx = list(df['condition'].unique())
#      18 # idx = [idx[2]]+idx[0:2]+idx[3:] # rearange for order
#
# File /mnt/md0/s236922/cowell-lab/repertoire_zoo/repertoire_zoo/bird.py:198, in load_gene_usage_group_data(repcalc_dir, groups, processing_stage, call_type, level, mode, productive, threshold, datapoints, categories)
#     196 for group_id, condition_name, *_ in groups:
#     197     path = f"{repcalc_dir}{group_id}.{processing_stage}.group.{call_type}.tsv"
# --> 198     df = pd.read_csv(path, sep='\t')
#     199     df = df[(df['level']==level) & (df['mode']==mode) & (df['productive']==productive)]
#     200     df = df.loc[:,['gene', 'duplicate_frequency_avg', 'duplicate_frequency_std', 'N']]
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/apps/miniconda3/envs/zoo/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/md0/Projects/MonsonLab/COVVAX/vdjserver/ee73a6fb-fc35-4eed-86c5-5adbebb97cf8-007/f805af34-f145-46b1-be17-a3634571fe3a.igblast.makedb.gene.clone.group.j_call.tsv'

# %% [markdown]
# # VJ Combo

# %% [markdown]
# ## Chord Diagram of VH:JH Gene Pairing

# %%
fig, axes = plot_grid(
    [lambda ax, group=group: gr.plot_vj_chord_diagram(
        df=br.load_and_prepare_data_vj_combo(
            repcalc_dir=repcalc_dir,
            group_id=group[0],
            combo_type='vj_combo',
            processing_stage='.igblast.makedb.gene.clone.group.'
        ),
        freq_col='duplicate_frequency_avg',
        ticks_interval=0.02,
        max_links=None,
        cmap=v_subgroup_cmap | j_subgroup_cmap,
        title=f'{group[1]}, N={len(group[2])}',
        ax=ax
    ) for group in groups_tuple if group[1] in hue_order],
    nrows=1,
    ncols=5,
    figsize=(60, 12),
    sharey=True,
    suptitle={'t':'Chord Diagram of VH:JH gene pairing', 'y':1.0, 'fontsize':24},
    projection='polar'
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 15
#       1 fig, axes = plot_grid(
#       2     [lambda ax, group=group: gr.plot_vj_chord_diagram(
#       3         df=br.load_and_prepare_data_vj_combo(
#       4             repcalc_dir=repcalc_dir,
#       5             group_id=group[0],
#       6             combo_type='vj_combo',
#       7             processing_stage='.igblast.makedb.gene.clone.group.'
#       8         ),
#       9         freq_col='duplicate_frequency_avg',
#      10         ticks_interval=0.02,
#      11         max_links=None,
#      12         cmap=v_subgroup_cmap | j_subgroup_cmap,
#      13         title=f'{group[1]}, N={len(group[2])}',
#      14         ax=ax
# ---> 15     ) for group in groups_tuple if group[1] in hue_order],
#      16     nrows=1,
#      17     ncols=5,
#      18     figsize=(60, 12),
#      19     sharey=True,
#      20     suptitle={'t':'Chord Diagram of VH:JH gene pairing', 'y':1.0, 'fontsize':24},
#      21     projection='polar'
#      22 )
#      24 fig.show()
#
# NameError: name 'hue_order' is not defined

# %% [markdown]
# # CDR3

# %% [markdown]
# ## Bar graph of CDR3 length

# %%
def plot1(ax):
    df = br.load_and_prepare_data_junction_aa(
        repcalc_dir=repcalc_dir,
        groups=groups_tuple,
        processing_stage='.igblast.makedb.allele.clone.group.',
        call_type='junction_aa_length'
    )
    
    gr.plot_junction_aa_length(
        df=df[(df['condition']!=control_group_name) & (df['condition'].isin(hue_order))],
        x_col='CDR3_LENGTH',
        y_col='CDR3_RELATIVE',
        hue_col='condition',
        palette=cond_cmap,
        legend=True,
        ax=ax,
        title={'t':'(A)', 'x':0, 'fontsize':12, 'weight':'bold'},
    )

    sns.lineplot(
        df[df['condition']==control_group_name],
        x='CDR3_LENGTH',
        y='CDR3_RELATIVE',
        label=control_group_name,
        color='k',
        ls='-',
        lw=2,
        ax=ax
    )

fig, axes = plot_grid(
    [plot1],
    ncols=1,
    nrows=1,
    figsize=(12,6),
    # sharex=True,
    sharey=True,
    suptitle={'t':'CDR3 Length', 'y':0.94, 'fontsize':20}
)

fig.show()

# add N for labels
condition_counts = {}
for group in groups_tuple:
    condition_counts[group[1]] = len(group[2])

for ax in axes:
    handles, lables = ax.get_legend_handles_labels()
    new_labels = [f'{condition}, N={int(condition_counts[condition])}' for condition in lables]
    ax.legend(handles, new_labels, title='Group', fontsize=8)
# Out:
# /mnt/md0/s236922/cowell-lab/repertoire_zoo/repertoire_zoo/bird.py:381: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_combined = pd.concat(dfs, ignore_index=True)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 31
#       9     gr.plot_junction_aa_length(
#      10         df=df[(df['condition']!=control_group_name) & (df['condition'].isin(hue_order))],
#      11         x_col='CDR3_LENGTH',
#    (...)     17         title={'t':'(A)', 'x':0, 'fontsize':12, 'weight':'bold'},
#      18     )
#      20     sns.lineplot(
#      21         df[df['condition']==control_group_name],
#      22         x='CDR3_LENGTH',
#    (...)     28         ax=ax
#      29     )
# ---> 31 fig, axes = plot_grid(
#      32     [plot1],
#      33     ncols=1,
#      34     nrows=1,
#      35     figsize=(12,6),
#      36     # sharex=True,
#      37     sharey=True,
#      38     suptitle={'t':'CDR3 Length', 'y':0.94, 'fontsize':20}
#      39 )
#      41 fig.show()
#      43 # add N for labels
#
# Cell In[10], line 168, in plot_grid(plots, nrows, ncols, figsize, sharex, sharey, suptitle, wspace, hspace, projection)
#     166         ax = fig.add_subplot(gs[row, col], projection=projection)
#     167     axes.append(ax)
# --> 168     plot(ax)
#     170 if sharex:
#     171     set_sharedx(axes)
#
# Cell In[25], line 10, in plot1(ax)
#       1 def plot1(ax):
#       2     df = br.load_and_prepare_data_junction_aa(
#       3         repcalc_dir=repcalc_dir,
#       4         groups=groups_tuple,
#       5         processing_stage='.igblast.makedb.allele.clone.group.',
#       6         call_type='junction_aa_length'
#       7     )
#       9     gr.plot_junction_aa_length(
# ---> 10         df=df[(df['condition']!=control_group_name) & (df['condition'].isin(hue_order))],
#      11         x_col='CDR3_LENGTH',
#      12         y_col='CDR3_RELATIVE',
#      13         hue_col='condition',
#      14         palette=cond_cmap,
#      15         legend=True,
#      16         ax=ax,
#      17         title={'t':'(A)', 'x':0, 'fontsize':12, 'weight':'bold'},
#      18     )
#      20     sns.lineplot(
#      21         df[df['condition']==control_group_name],
#      22         x='CDR3_LENGTH',
#    (...)     28         ax=ax
#      29     )
#
# NameError: name 'hue_order' is not defined

# %% [markdown]
# ## Headgehog of Overall RF

# %%
figsize = (24,20)
nrows = 1
ncols = 5

fig, axes = plot_grid(
    [lambda ax, group=group: gr.plot_mutational_hedgehog(
        df=br.load_and_prepare_mutation_data(
            mutation_data_dir=repcalc_dir,
            repertoire_groups=[group],
            trim_codons=16,
            processing_stage='igblast.makedb.gene.clone.mutations'
        ),
        figsize=figsize,
        title={'t':f'{group[1]}, N={len(group[2])}', 'fontsize':16},
        ax=ax
    ) for group in groups_tuple if group[1] in hue_order],
    nrows=nrows,
    ncols=ncols,
    figsize=((figsize[0]*ncols), (figsize[1]*nrows)),
    sharey=True,
    suptitle={'t':'Mutational Replacement Frequency Diagram', 'y':0.94, 'fontsize':26},
    # suptitle='Chord Diagram of VH:JH gene pairing',
    projection='polar',
)

for ax in axes:
    ax.yaxis.grid(True)
    ax.yaxis.set_major_locator(MaxNLocator(7))

    ticks = ax.get_yticks()
    ax.set_yticks([t for t in ticks if t >=0])  # remove the last one

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 16
#       2 nrows = 1
#       3 ncols = 5
#       5 fig, axes = plot_grid(
#       6     [lambda ax, group=group: gr.plot_mutational_hedgehog(
#       7         df=br.load_and_prepare_mutation_data(
#       8             mutation_data_dir=repcalc_dir,
#       9             repertoire_groups=[group],
#      10             trim_codons=16,
#      11             processing_stage='igblast.makedb.gene.clone.mutations'
#      12         ),
#      13         figsize=figsize,
#      14         title={'t':f'{group[1]}, N={len(group[2])}', 'fontsize':16},
#      15         ax=ax
# ---> 16     ) for group in groups_tuple if group[1] in hue_order],
#      17     nrows=nrows,
#      18     ncols=ncols,
#      19     figsize=((figsize[0]*ncols), (figsize[1]*nrows)),
#      20     sharey=True,
#      21     suptitle={'t':'Mutational Replacement Frequency Diagram', 'y':0.94, 'fontsize':26},
#      22     # suptitle='Chord Diagram of VH:JH gene pairing',
#      23     projection='polar',
#      24 )
#      26 for ax in axes:
#      27     ax.yaxis.grid(True)
#
# NameError: name 'hue_order' is not defined

# %%
# useful section for making a grid

# rf_lengths=[None, '14', '15', '18', '19', '22', '23']
# figsize=(24,20)

# # create figure
# fig, axes = plt.subplots(7, 5, figsize=(60,80), subplot_kw={'projection': 'polar'})

# row_i = 0
# col_i = 0
# for i, group in enumerate(diag_hi_groups_3t7):
    
#     row_i = i//5
#     col_i = i%5

#     gr.plot_mutational_hedgehog(
#         df=br.load_and_prepare_mutation_data(
#             mutation_data_dir=repcalc_dir,
#             repertoire_groups=[group],
#             trim_codons=16,
#             processing_stage='igblast.makedb.gene.clone.mutations'
#         ),
#         figsize=figsize,
#         title={'t':f'{group[1]}, N={len(group[2])}', 'fontsize':16},
#         ax=axes[row_i, col_i]
#     )

# for ax_r in axes:
#     for ax in ax_r:
#         ax.yaxis.grid(True)
#         ax.yaxis.set_major_locator(MaxNLocator(7))
#         ax.set_ylim(top=0.85)

#         ticks = ax.get_yticks()
#         ax.set_yticks([t for t in ticks if t >=0])  # remove the last one

# fig.tight_layout()
# fig.suptitle('Hedgehog of CDR3 Spikes', fontsize=24, y=1.02)
# fig.show()

# %% [markdown]
# ## Clonal Expansion

# %% [markdown]
# ### Abundance

# %%
processing_stage = 'igblast.makedb.allele.clone'
clone_tool = 'repcalc' # repcalc, changeo

df = br.load_and_prepare_clonal_abundance_group_data(
    repcalc_dir,
    [group for group in groups_tuple if group[1] in hue_order],
    all_groups=repertoire_groups,
    all_repertoires=repertoires,
    clone_tool=clone_tool,
    processing_stage=processing_stage
)

fig, ax = gr.plot_clonal_abundance(
    df,
    y_col = 'abundance',
    figsize=(32, 24),
    title = f'Clonal Abundance Tool Type: {clone_tool}, Filter: Group',
    legend_title = 'Group Name',
    hue='condition'
)
handles, lables = ax.get_legend_handles_labels()
condition_counts = {e[1] : e[2] for e in groups_tuple}
new_labels = [f'{condition}, N={int(len(condition_counts[condition]))}' for condition in lables]
ax.legend(handles, new_labels, title='Group', loc='center left', bbox_to_anchor=(1, 0.5))
fig.show()

# %% [markdown]
# ### Cumulative Abundance

# %%
figsize = (24,20)
nrows = 1
ncols = 5

fig, axes = plot_grid(
    [lambda ax, group=group: gr.plot_clonal_abundance(
        df=br.load_and_prepare_clonal_abundance_group_data(
            repcalc_dir,
            [group],
            all_groups=repertoire_groups,
            all_repertoires=repertoires,
            clone_tool=clone_tool,
            processing_stage=processing_stage
        ),
        y_col = 'cumulative_abundance',
        figsize=figsize,
        title = f'{group[1]}',
        legend_title = 'Sample',
        hue='sample_id',
        ax=ax
    ) for group in groups_tuple if group[1] in hue_order],
    nrows=nrows,
    ncols=ncols,
    figsize=((figsize[0]*ncols), (figsize[1]*nrows)),
    sharey=True,
    suptitle={'t':'Cumulative Abyndance', 'y':0.94, 'fontsize':26},
    
)

for ax in axes:
    ax.yaxis.grid(True)
    ax.yaxis.set_major_locator(MaxNLocator(7))

    ticks = ax.get_yticks()
    ax.set_yticks([t for t in ticks if t >=0])  # remove the last one

fig.show()

# %% [markdown]
# ### Expansion

# %%
# processing_stage = 'igblast.makedb.allele.clone'
# clone_tool = 'repcalc' # repcalc, changeo

# df = br.load_and_prepare_clonal_abundance_group_data(
#     repcalc_dir,
#     diag_hi_groups_3t7,
#     all_groups=repertoire_groups,
#     all_repertoires=repertoires,
#     clone_tool=clone_tool,
#     processing_stage=processing_stage
# )

# # Assign a distinct color to each category
# unique_labels = df['condition'].unique()
# palette = sns.color_palette('tab10', len(unique_labels))
# color_map = dict(zip(unique_labels, palette))

# plt.figure(figsize=(12, 8))
# for label in unique_labels:
#     subset = df[(df['condition']==label)]
#     subset = subset.sort_values('abundance', ascending=False)
#     subset['group_rank'] = range(1, subset.shape[0]+1)
#     subset = subset[subset['group_rank']<6]

#     plt.scatter(
#         subset['abundance'], subset['seq_freq'],
#         s=(1/(subset['group_rank']**2))*1000,          # scale size if needed
#         color=cond_cmap[label],
#         alpha=0.7,
#         edgecolor='k',
#         label=label
#     )
# plt.xlabel('Abundance')
# plt.ylabel('Sequence Freq')
# plt.legend(title='Condition (Color) / Rank (Size)', bbox_to_anchor=(1.0,0.5))
# plt.title('Test Figure')
# # plt.tight_layout()

# %%
# percentage = False
# similarity_metrics = ['simpson_coefficient', 'jaccard']
# tissue_types = ['cancer_vs_benign', 'all_tissue', 'all_blood', 'tissue_vs_blood']
# tissue_types = ['cancer_vs_benign']
# sharings = ['cdr3_aa_sharing', 'cdr3_nucleotide_sharing', 'cdr3_vj_aa_sharing']
# sharing = sharings[0]


# df['ss_id'] = str(df['clone_id']) + "_" + df['sample_id'] + "_" +  df['condition']
# # old_subjects = ['13N-1', '16M', '17M', '17N', '19M', '19N-1', '46150-1', '46346-1']
# # old_subjects = ['13N-1', '16M', '17M', '17N', '19M', '19N-1']
# #removing old samples from library 25 and 26
# # selected_samples = sample_info_df[~(sample_info_df.subject_id.isin(old_subjects))]
# # selected_samples = selected_samples.sort_values(by = ['subject_id','diagnosis', 'sample_id', 'tissue'])

# repertoire_ids = df.repertoire_id.values
# sample_ids = df.ss_id.values

# path = f"{repcalc_dir}{processing_stage}.{sharing}.tsv"
# df = pd.read_csv(path, sep='\t', index_col=0)
# df = df.loc[repertoire_ids, repertoire_ids]
# df.index = sample_ids
# df.columns = sample_ids

# common_matrix = df.copy()
# N = common_matrix.shape[0]
# pairs = []

# for i in range(N):
#     for j in range(i+1, N):  # upper triangle, no diagonal
#         A_count = common_matrix.iloc[i, i]
#         B_count = common_matrix.iloc[j, j]
#         SampleA_name = common_matrix.index[i]
#         SampleB_name = common_matrix.index[j]
#         common = common_matrix.iloc[i, j]
#         overlap_percent_j = common /((A_count+ B_count)-common) * 100 if min(A_count, B_count) > 0 else 0
#         overlap_percent_s = common /min(A_count, B_count)* 100 if min(A_count, B_count) > 0 else 0
#         overlap_percent_a_in_b = common / A_count * 100 if min(A_count, B_count) > 0 else 0
#         overlap_percent_b_in_a = common / B_count * 100 if min(A_count, B_count) > 0 else 0
#         pairs.append({
#             'SampleA_count': A_count,
#             'SampleB_count': B_count,
#             'Common_count': common,
#             'Overlap_percent_jaccard': overlap_percent_j,
#             'Overlap_percent_simpson': overlap_percent_s,
#             'overlap_percent_a_in_b': overlap_percent_a_in_b,
#             'overlap_percent_b_in_a': overlap_percent_b_in_a,
#             'SampleA_name': SampleA_name,
#             'SampleB_name': SampleB_name
#         })

# df_pairs = pd.DataFrame(pairs)
# df_pairs = df_pairs[df_pairs.Overlap_percent_jaccard > 10]
# print(df_pairs.shape)
# print(df_pairs)
# # Plot
# plt.figure(figsize=(20,16))
# scatter = plt.scatter(
#     df_pairs['SampleA_count'], 
#     df_pairs['SampleB_count'], 
#     s=df_pairs['Common_count'],  
#     c=df_pairs['Overlap_percent_jaccard'], 
#     cmap='viridis', 
#     alpha=0.7, 
#     edgecolors='k'
# )

# plt.colorbar(scatter, label='Overlap % (relative to smaller sample)')
# plt.xlabel('Rearrangement Count Sample A')
# plt.ylabel('Rearrangement Count Sample B')
# plt.title('Scatter Plot of Sample Sizes vs. Overlap')
# plt.grid(True)

# # Add annotations for each point
# for idx, row in df_pairs.iterrows():
#     label = f"{row['SampleA_name']} - {row['SampleB_name']}"
#     plt.annotate(label, (row['SampleA_count'], row['SampleB_count']),
#                  textcoords="offset points", xytext=(5,-5), ha='right', fontsize=8)

# plt.show()

# %% [markdown]
# ### Diversity Curve

# %%
dfs = []
for i, (group_id, group_name, *_) in enumerate([group for group in groups_tuple if group[1] in hue_order]):
        
    df = br.load_diversity_group_data(
        data_dir=repcalc_dir,
        repertoire_group=repertoire_groups[group_id],
        processing_stage='igblast.makedb.gene.clone'
    )
    dfs.append(df)
df = pd.concat(dfs)

fig, ax = gr.plot_diversity_curve(
    df=df,
    title='Diversity Curve',
    legend=True
)

handles, lables = ax.get_legend_handles_labels()
condition_counts = {e[1] : len(e[2]) for e in groups_tuple}
new_labels = [f'{condition}, N={int(condition_counts[condition])}' for condition in lables]
ax.legend(handles, new_labels, title='Group', loc='center left', bbox_to_anchor=(1, 0.5))
fig.show()

# %% [markdown]
# ### Normalized Shannon Entropy

# %%
df = br.load_diversity_multiple_group_data(
    data_dir=repcalc_dir,
    repertoire_groups=[group for group in groups_tuple if group[1] in hue_order],
    processing_stage='igblast.makedb.gene.clone',
    all_groups=repertoire_groups
)

fig, ax = gr.plot_diversity_boxplot(
    df=df,
    hue='condition',
    legend=False
)

labels = ax.get_xticklabels()
condition_counts = {e[1] : len(e[2]) for e in groups_tuple}
new_labels = [Text(l.get_position()[0], l.get_position()[1], f'{l.get_text()}\nN={int(condition_counts[l.get_text()])}') for l in labels]
ax.set_xticklabels(new_labels)

fig.show()

# %% [markdown]
# ## RF and R:S Ratio in CDR and FR

# %% [markdown]
# ### Dataframe setup

# %%
file_path = f"{repcalc_dir}igblast.makedb.gene.clone.mutations.repertoire_group.frequency.mutational_report.csv"
# file_path = f"{repcalc_dir}igblast.makedb.gene.clone.mutations.repertoire.frequency.mutational_report.csv"
group_muts = pd.read_csv(file_path, index_col='repertoire_group_id')
group_muts.columns.to_list()
ratio_cols = [ 'mu_ratio_fwr_avg',
 'mu_ratio_fwr_std',
 'mu_ratio_fwr_N',
 'mu_ratio_fwr_r_avg',
 'mu_ratio_fwr_r_std',
 'mu_ratio_fwr_r_N',
 'mu_ratio_fwr_s_avg',
 'mu_ratio_fwr_s_std',
 'mu_ratio_fwr_s_N',
 'mu_ratio_cdr_avg',
 'mu_ratio_cdr_std',
 'mu_ratio_cdr_N',
 'mu_ratio_cdr_r_avg',
 'mu_ratio_cdr_r_std',
 'mu_ratio_cdr_r_N',
 'mu_ratio_cdr_s_avg',
 'mu_ratio_cdr_s_std',
 'mu_ratio_cdr_s_N',
 'mu_rsratio_cdr_avg',
 'mu_rsratio_cdr_std',
 'mu_rsratio_cdr_N',
 'mu_rsratio_fwr_avg',
 'mu_rsratio_fwr_std',
 'mu_rsratio_fwr_N',
 'mu_ratio_fwr_aa_avg',
 'mu_ratio_fwr_aa_std',
 'mu_ratio_fwr_aa_N',
 'mu_ratio_fwr_r_aa_avg',
 'mu_ratio_fwr_r_aa_std',
 'mu_ratio_fwr_r_aa_N',
 'mu_ratio_fwr_s_aa_avg',
 'mu_ratio_fwr_s_aa_std',
 'mu_ratio_fwr_s_aa_N',
 'mu_ratio_cdr_aa_avg',
 'mu_ratio_cdr_aa_std',
 'mu_ratio_cdr_aa_N',
 'mu_ratio_cdr_r_aa_avg',
 'mu_ratio_cdr_r_aa_std',
 'mu_ratio_cdr_r_aa_N',
 'mu_ratio_cdr_s_aa_avg',
 'mu_ratio_cdr_s_aa_std',
 'mu_ratio_cdr_s_aa_N',
 'mu_rsratio_cdr_aa_avg',
 'mu_rsratio_cdr_aa_std',
 'mu_rsratio_cdr_aa_N',
 'mu_rsratio_fwr_aa_avg',
 'mu_rsratio_fwr_aa_std',
 'mu_rsratio_fwr_aa_N',]

freq_cols = [
    'mu_freq_avg',
    'mu_freq_std',
    'mu_freq_N',
    'mu_freq_r_avg',
    'mu_freq_r_std',
    'mu_freq_r_N',
    'mu_freq_s_avg',
    'mu_freq_s_std',
    'mu_freq_s_N',
    'mu_freq_aa_avg',
    'mu_freq_aa_std',
    'mu_freq_aa_N',
    'mu_freq_r_aa_avg',
    'mu_freq_r_aa_std',
    'mu_freq_r_aa_N',
    'mu_freq_s_aa_avg',
    'mu_freq_s_aa_std',
    'mu_freq_s_aa_N',
    'mu_freq_fwr_avg',
    'mu_freq_fwr_std',
    'mu_freq_fwr_N',
    'mu_freq_fwr_r_avg',
    'mu_freq_fwr_r_std',
    'mu_freq_fwr_r_N',
    'mu_freq_fwr_s_avg',
    'mu_freq_fwr_s_std',
    'mu_freq_fwr_s_N',
    'mu_freq_cdr_avg',
    'mu_freq_cdr_std',
    'mu_freq_cdr_N',
    'mu_freq_cdr_r_avg',
    'mu_freq_cdr_r_std',
    'mu_freq_cdr_r_N',
    'mu_freq_cdr_s_avg',
    'mu_freq_cdr_s_std',
    'mu_freq_cdr_s_N',
    'mu_freq_fwr1_avg',
    'mu_freq_fwr1_std',
    'mu_freq_fwr1_N',
    'mu_freq_fwr1_r_avg',
    'mu_freq_fwr1_r_std',
    'mu_freq_fwr1_r_N',
    'mu_freq_fwr1_s_avg',
    'mu_freq_fwr1_s_std',
    'mu_freq_fwr1_s_N',
    'mu_freq_cdr1_avg',
    'mu_freq_cdr1_std',
    'mu_freq_cdr1_N',
    'mu_freq_cdr1_r_avg',
    'mu_freq_cdr1_r_std',
    'mu_freq_cdr1_r_N',
    'mu_freq_cdr1_s_avg',
    'mu_freq_cdr1_s_std',
    'mu_freq_cdr1_s_N',
    'mu_freq_fwr2_avg',
    'mu_freq_fwr2_std',
    'mu_freq_fwr2_N',
    'mu_freq_fwr2_r_avg',
    'mu_freq_fwr2_r_std',
    'mu_freq_fwr2_r_N',
    'mu_freq_fwr2_s_avg',
    'mu_freq_fwr2_s_std',
    'mu_freq_fwr2_s_N',
    'mu_freq_cdr2_avg',
    'mu_freq_cdr2_std',
    'mu_freq_cdr2_N',
    'mu_freq_cdr2_r_avg',
    'mu_freq_cdr2_r_std',
    'mu_freq_cdr2_r_N',
    'mu_freq_cdr2_s_avg',
    'mu_freq_cdr2_s_std',
    'mu_freq_cdr2_s_N',
    'mu_freq_fwr3_avg',
    'mu_freq_fwr3_std',
    'mu_freq_fwr3_N',
    'mu_freq_fwr3_r_avg',
    'mu_freq_fwr3_r_std',
    'mu_freq_fwr3_r_N',
    'mu_freq_fwr3_s_avg',
    'mu_freq_fwr3_s_std',
    'mu_freq_fwr3_s_N',
    'mu_freq_fwr_aa_avg',
    'mu_freq_fwr_aa_std',
    'mu_freq_fwr_aa_N',
    'mu_freq_fwr_r_aa_avg',
    'mu_freq_fwr_r_aa_std',
    'mu_freq_fwr_r_aa_N',
    'mu_freq_fwr_s_aa_avg',
    'mu_freq_fwr_s_aa_std',
    'mu_freq_fwr_s_aa_N',
    'mu_freq_cdr_aa_avg',
    'mu_freq_cdr_aa_std',
    'mu_freq_cdr_aa_N',
    'mu_freq_cdr_r_aa_avg',
    'mu_freq_cdr_r_aa_std',
    'mu_freq_cdr_r_aa_N',
    'mu_freq_cdr_s_aa_avg',
    'mu_freq_cdr_s_aa_std',
    'mu_freq_cdr_s_aa_N',
    'mu_freq_fwr1_aa_avg',
    'mu_freq_fwr1_aa_std',
    'mu_freq_fwr1_aa_N',
    'mu_freq_fwr1_r_aa_avg',
    'mu_freq_fwr1_r_aa_std',
    'mu_freq_fwr1_r_aa_N',
    'mu_freq_fwr1_s_aa_avg',
    'mu_freq_fwr1_s_aa_std',
    'mu_freq_fwr1_s_aa_N',
    'mu_freq_cdr1_aa_avg',
    'mu_freq_cdr1_aa_std',
    'mu_freq_cdr1_aa_N',
    'mu_freq_cdr1_r_aa_avg',
    'mu_freq_cdr1_r_aa_std',
    'mu_freq_cdr1_r_aa_N',
    'mu_freq_cdr1_s_aa_avg',
    'mu_freq_cdr1_s_aa_std',
    'mu_freq_cdr1_s_aa_N',
    'mu_freq_fwr2_aa_avg',
    'mu_freq_fwr2_aa_std',
    'mu_freq_fwr2_aa_N',
    'mu_freq_fwr2_r_aa_avg',
    'mu_freq_fwr2_r_aa_std',
    'mu_freq_fwr2_r_aa_N',
    'mu_freq_fwr2_s_aa_avg',
    'mu_freq_fwr2_s_aa_std',
    'mu_freq_fwr2_s_aa_N',
    'mu_freq_cdr2_aa_avg',
    'mu_freq_cdr2_aa_std',
    'mu_freq_cdr2_aa_N',
    'mu_freq_cdr2_r_aa_avg',
    'mu_freq_cdr2_r_aa_std',
    'mu_freq_cdr2_r_aa_N',
    'mu_freq_cdr2_s_aa_avg',
    'mu_freq_cdr2_s_aa_std',
    'mu_freq_cdr2_s_aa_N',
    'mu_freq_fwr3_aa_avg',
    'mu_freq_fwr3_aa_std',
    'mu_freq_fwr3_aa_N',
    'mu_freq_fwr3_r_aa_avg',
    'mu_freq_fwr3_r_aa_std',
    'mu_freq_fwr3_r_aa_N',
    'mu_freq_fwr3_s_aa_avg',
    'mu_freq_fwr3_s_aa_std',
    'mu_freq_fwr3_s_aa_N'
]

ratio_df = group_muts.loc[:,ratio_cols]
ratio_df['rearrangement'] = ratio_df.index.to_series().str.extract(r'-(\d+)$')[0].fillna('All').astype(str)
ratio_df['parent_group'] = [repertoire_groups[ratio_df.index[i]].get('repertoire_group_name') if i < 5 else ' '.join(repertoire_groups[ratio_df.index[i]].get('repertoire_group_name').split(' ')[0:-1]) for i in range(ratio_df.shape[0])]
ratio_df = ratio_df.loc[:,ratio_df.columns[-2:].to_list()+ratio_df.columns[:-2].to_list()]
ratio_df = ratio_df.reset_index()
ratio_df['repertoire_group_name'] = [repertoire_groups[rgid].get('repertoire_group_name') for rgid in ratio_df.loc[:,'repertoire_group_id']]
ratio_df = ratio_df.loc[:,ratio_df.columns[0:3].to_list()+[ratio_df.columns[-1]]+ratio_df.columns[3:-1].to_list()]

freq_df = group_muts.loc[:,freq_cols]
freq_df['rearrangement'] = freq_df.index.to_series().str.extract(r'-(\d+)$')[0].fillna('All').astype(str)
freq_df['parent_group'] = [repertoire_groups[freq_df.index[i]].get('repertoire_group_name') if i < 5 else ' '.join(repertoire_groups[freq_df.index[i]].get('repertoire_group_name').split(' ')[0:-1]) for i in range(freq_df.shape[0])]
freq_df = freq_df.loc[:,freq_df.columns[-2:].to_list()+freq_df.columns[:-2].to_list()]
freq_df = freq_df.reset_index()
freq_df['repertoire_group_name'] = [repertoire_groups[rgid].get('repertoire_group_name') for rgid in freq_df.loc[:,'repertoire_group_id']]
freq_df = freq_df.loc[:,freq_df.columns[0:3].to_list()+[freq_df.columns[-1]]+freq_df.columns[3:-1].to_list()]

groups_tuple_repnum_map = {e[1]:len(e[2]) for e in groups_tuple}

# %% [markdown]
# ### Heatmaps

# %% [markdown]
# #### Mutation Frequency FWR

# %%
idx = list(freq_df['parent_group'].unique())

value_cols = ['mu_freq_fwr_aa_avg', 'mu_freq_fwr_r_aa_avg', 'mu_freq_fwr_s_aa_avg']
# sns.heatmap(subset)

fig, axes = plt.subplots(3, 1, figsize=(12,24))

for i, value in enumerate(value_cols):
    matrix = freq_df.pivot(
        index="parent_group",
        columns="rearrangement",
        values=value
    ).reindex(idx)

    # keep only one control group
    one_control_mat = matrix.drop(matrix.index[0], axis=0)

    # make normalized matrix
    norm_mat = norm_cols(one_control_mat, 'difference')

    # make annotation matrix
    annot_mat = make_annotation_mat(one_control_mat, norm_mat, 4, 4)

    sns.heatmap(
        norm_mat,
        annot=annot_mat,
        fmt='',
        cmap="RdBu_r",
        vmin=-0.08,
        vmax=0.08,
        ax=axes[i]
    )

    yticklabels = [f'{e.get_text()}\n(N = {groups_tuple_repnum_map[e.get_text()]})' for e in  axes[i].get_yticklabels()]
    axes[i].set_yticklabels(yticklabels)
    axes[i].set_title(value)

fig.show()
# ax.set_title('(A)', x=-0.4, fontsize=14, weight='bold')
# ax.set_ylabel('Repertoire Group')
# ax.set_xlabel('Gene Family')

# %% [markdown]
# #### Mutation Frequency CDR

# %%
idx = list(freq_df['parent_group'].unique())

value_cols = ['mu_freq_cdr_aa_avg', 'mu_freq_cdr_r_aa_avg', 'mu_freq_cdr_s_aa_avg']
# sns.heatmap(subset)

fig, axes = plt.subplots(3, 1, figsize=(12,24))

for i, value in enumerate(value_cols):
    matrix = freq_df.pivot(
        index="parent_group",
        columns="rearrangement",
        values=value
    ).reindex(idx)

    # keep only one control group
    one_control_mat = matrix.drop(matrix.index[0], axis=0)

    # make normalized matrix
    norm_mat = norm_cols(one_control_mat, 'difference')

    # make annotation matrix
    annot_mat = make_annotation_mat(one_control_mat, norm_mat, 4, 4)

    sns.heatmap(
        norm_mat,
        annot=annot_mat,
        fmt='',
        cmap="RdBu_r",
        vmin=-0.17,
        vmax=0.17,
        ax=axes[i]
    )

    yticklabels = [f'{e.get_text()}\n(N = {groups_tuple_repnum_map[e.get_text()]})' for e in  axes[i].get_yticklabels()]
    axes[i].set_yticklabels(yticklabels)
    axes[i].set_title(value)

fig.show()
# ax.set_title('(A)', x=-0.4, fontsize=14, weight='bold')
# ax.set_ylabel('Repertoire Group')
# ax.set_xlabel('Gene Family')

# %% [markdown]
# #### Mutation Ratio FWR

# %%
idx = list(ratio_df['parent_group'].unique())

value_cols = ['mu_ratio_fwr_aa_avg', 'mu_ratio_fwr_r_aa_avg', 'mu_ratio_fwr_s_aa_avg']
# sns.heatmap(subset)

fig, axes = plt.subplots(3, 1, figsize=(12,24))

for i, value in enumerate(value_cols):
    matrix = ratio_df.pivot(
        index="parent_group",
        columns="rearrangement",
        values=value
    ).reindex(idx)

    # keep only one control group
    one_control_mat = matrix.drop(matrix.index[1], axis=0)

    # make normalized matrix
    norm_mat = norm_cols(one_control_mat, 'difference')

    # make annotation matrix
    annot_mat = make_annotation_mat(one_control_mat, norm_mat, 4, 4)

    sns.heatmap(
        norm_mat,
        annot=annot_mat,
        fmt='',
        cmap="RdBu_r",
        vmin=-0.1,
        vmax=0.1,
        ax=axes[i]
    )

    yticklabels = [f'{e.get_text()}\n(N = {groups_tuple_repnum_map[e.get_text()]})' for e in  axes[i].get_yticklabels()]
    axes[i].set_yticklabels(yticklabels)
    axes[i].set_title(value)

fig.show()
# ax.set_title('(A)', x=-0.4, fontsize=14, weight='bold')
# ax.set_ylabel('Repertoire Group')
# ax.set_xlabel('Gene Family')

# %% [markdown]
# #### Mutation Ratio CDR

# %%
idx = list(ratio_df['parent_group'].unique())

value_cols = ['mu_ratio_cdr_aa_avg', 'mu_ratio_cdr_r_aa_avg', 'mu_ratio_cdr_s_aa_avg']
# sns.heatmap(subset)

fig, axes = plt.subplots(3, 1, figsize=(12,24))

for i, value in enumerate(value_cols):
    matrix = ratio_df.pivot(
        index="parent_group",
        columns="rearrangement",
        values=value
    ).reindex(idx)

    # keep only one control group
    one_control_mat = matrix.drop(matrix.index[1], axis=0)

    # make normalized matrix
    norm_mat = norm_cols(one_control_mat, 'difference')

    # make annotation matrix
    annot_mat = make_annotation_mat(one_control_mat, norm_mat, 4, 4)

    sns.heatmap(
        norm_mat,
        annot=annot_mat,
        fmt='',
        cmap="RdBu_r",
        vmin=-0.1,
        vmax=0.1,
        ax=axes[i]
    )

    yticklabels = [f'{e.get_text()}\n(N = {groups_tuple_repnum_map[e.get_text()]})' for e in  axes[i].get_yticklabels()]
    axes[i].set_yticklabels(yticklabels)
    axes[i].set_title(value)

fig.show()
# ax.set_title('(A)', x=-0.4, fontsize=14, weight='bold')
# ax.set_ylabel('Repertoire Group')
# ax.set_xlabel('Gene Family')

# %% [markdown]
# ### Tables

# %% [markdown]
# #### Mutation RS Ratio FWR

# %%
idx = list(ratio_df['parent_group'].unique())
# idx = [idx[2]]+idx[0:2]+idx[3:] # rearange for order

# means to view data easily (temp)
matrix = ratio_df.pivot_table(
    index="parent_group",
    columns="rearrangement",
    values="mu_rsratio_fwr_aa_avg"
).reindex(idx)
matrix

print(tabulate(matrix, tablefmt='heavy_grid', headers=matrix.columns))

# %% [markdown]
# #### Mutation RS Ratio CDR

# %%
idx = list(ratio_df['parent_group'].unique())

matrix = ratio_df.pivot_table(
    index="parent_group",
    columns="rearrangement",
    values="mu_rsratio_cdr_aa_avg"
).reindex(idx)
matrix

print(tabulate(matrix, tablefmt='heavy_grid', headers=matrix.columns))

# %% [markdown]
# #### Mutation Ratio

# %%
cols = ['mu_ratio_fwr_aa', 'mu_ratio_cdr_aa', 'mu_ratio_fwr_r_aa', 'mu_ratio_fwr_s_aa', 'mu_ratio_cdr_r_aa', 'mu_ratio_cdr_s_aa', 'mu_rsratio_fwr_aa', 'mu_rsratio_cdr_aa']
true_cols = [[col+'_avg', col+'_std', col+'_N'] for col in cols]
true_cols = [col for true_col in true_cols for col in true_col]

true_cols
df = ratio_df.loc[:,['repertoire_group_name']+true_cols]
df = df.set_index('repertoire_group_name')

compressed_df = pd.DataFrame(index=df.index, columns=cols)

for col in cols:
    compressed_df.loc[:,col] = df.loc[:,col+'_avg'].astype(float).round(4).astype(str) + \
        ' ± ' + df.loc[:,col+'_std'].astype(float).round(6).astype(str) + \
        '\n' + '(N=' + df.loc[:,col+'_N'].astype(str) + ')'

print(compressed_df.to_markdown())
compressed_df.to_excel('mu_ratio_table.xlsx')

# %% [markdown]
# #### Mutation Frequency

# %%
cols = ['mu_freq_fwr_aa', 'mu_freq_cdr_aa', 'mu_freq_fwr_r_aa', 'mu_freq_fwr_s_aa', 'mu_freq_cdr_r_aa', 'mu_freq_cdr_s_aa']
true_cols = [[col+'_avg', col+'_std', col+'_N'] for col in cols]
true_cols = [col for true_col in true_cols for col in true_col]

true_cols
df = freq_df.loc[:,['repertoire_group_name']+true_cols]
df = df.set_index('repertoire_group_name')

compressed_df = pd.DataFrame(index=df.index, columns=cols)

for col in cols:
    compressed_df.loc[:,col] = df.loc[:,col+'_avg'].astype(float).round(4).astype(str) + \
        ' ± ' + df.loc[:,col+'_std'].astype(float).round(6).astype(str) + \
        '\n' + '(N=' + df.loc[:,col+'_N'].astype(str) + ')'

# print(compressed_df.to_markdown())
print(tabulate(compressed_df, tablefmt='heavy_grid', headers=['Group Name']+cols))
compressed_df.to_excel('mu_freq_table.xlsx')

# %% [markdown]
# #### Mutation Ratio/RS Ratio FWR/CDR

# %%
out_ratio_df = ratio_df.loc[:,['rearrangement', 'parent_group']+[col+'_avg' for col in cols]]
out_ratio_df = out_ratio_df.set_index([ratio_df['repertoire_group_id'],'rearrangement', 'parent_group'])
out_ratio_df = out_ratio_df.rename(columns={col:'_'.join(col.split('_')[:-2]) for col in out_ratio_df.columns})
temp_ratio_df = ratio_df.set_index('repertoire_group_id')
for col in out_ratio_df:
    out_ratio_df[col] = out_ratio_df[col].round(5).astype(str) + ' ± ' + temp_ratio_df[col+'_std'].round(5).astype(str) +'\n(N='+temp_ratio_df[col+'_N'].astype(str)+')'
    # print(a)
    # break
# ratio_df.loc[:,['rearrangement', 'parent_group']+[col+'_std' for col in cols]]
# ratio_df.loc[:,['rearrangement', 'parent_group']+[col+'_N' for col in cols]]
# out_ratio_df
print(tabulate(out_ratio_df, tablefmt='heavy_grid', headers=['(group id, rearrangement filter length, group)']+cols))

# %% [markdown]
# ### Bar Graphs

# %% [markdown]
# #### Mutation Ratio FWR

# %%
gr.plot_ratio(
    ratio_df,
    region='mu_ratio_fwr',
    errorbar='se',
    ylim=(0.6,0.8),
    title='mu_ratio_fwr'
)

# %% [markdown]
# #### Mutation Ratio CDR

# %%
gr.plot_ratio(
    ratio_df,
    region='mu_ratio_cdr',
    errorbar='se',
    ylim=(0.2,0.4),
    title='mu_ratio_cdr'
)

# %% [markdown]
# #### Mutation RS Ratio FWR

# %%
gr.plot_ratio(
    ratio_df,
    region='mu_rsratio_fwr',
    errorbar='se',
    # ylim=(0.2,0.4),
    title='mu_rsratio_fwr'
)

# %% [markdown]
# #### Mutation RS Ratio CDR

# %%
gr.plot_ratio(
    ratio_df,
    region='mu_rsratio_cdr',
    errorbar='se',
    # ylim=(0.2,0.4),
    title='mu_rsratio_cdr'
)

# %% [markdown]
# ## AA Sharing

# %%
# plot_type = 'between' if len(groups) == 2 else 'within'
plot_type = 'between'

sharing = 'cdr3_aa_sharing'
processing_stage = 'repertoire.shared.matrix'
# processing_stage = 'group.summary_comparison'

similarity_metric = 'a_in_b' #jaccard, simpson_coefficient, a_in_b, b_in_a
# similarity_metric = 'b_in_a' #jaccard, simpson_coefficient, a_in_b, b_in_a
percentage = True

# setup to compare against healthy control (diag_hi_groups[0])
for i, group in enumerate([group for group in groups_tuple if group[1] in hue_order]):
    if group[1] == control_group_name:
        control = group
        break

for i, group in enumerate([group for group in groups_tuple if group[1] in hue_order]):
    if group == control:
        continue
    matrix = br.load_shared_cdr3_aa_data(
        repcalc_dir,
        repertoire_groups, 
        sample_info_df, 
        groups=[control, group], 
        percentage=percentage,
        similarity_metric=similarity_metric,
        sharing=sharing,
        processing_stage=processing_stage,
        plot_type=plot_type
    )
    matrix = matrix.sort_index().sort_index(axis=1)
    fig, ax = gr.plot_cdr3_aa_sharing_heatmap(matrix, cmap = 'viridis', figsize = (36, 30))
    plt.title(f"Heatmap of {sharing} {plot_type} group")
    plt.tight_layout()

# %% [markdown]
# ## Sequence Count

# %%
df = br.load_cdr3_sequences_each_repertoire(
    repcalc_dir=repcalc_dir,
    repertoire_id=data['Repertoire'][0]['repertoire_id'],
    sharing='cdr3_aa_sharing',
    processing_stage='repertoire'
)

fig, ax = gr.plot_cdr3_sequence_count(
    df=df,
    abundance=True,
    top_n=20,
    figsize=(16,8)
)

fig.show()

# %% [markdown]
# ## Unique Number of Sequences

# %%
sharing='cdr3_aa_sharing'
processing_stage='repertoire'

# setup to compare against healthy control (diag_hi_groups[0])
for i, group in enumerate([group for group in groups_tuple if group[1] in hue_order]):
    if group[1] == control_group_name:
        control = group
        break
    
for i, group in enumerate([group for group in groups_tuple if group[1] in hue_order]):
    if group == control:
        continue
    df = br.load_unique_cdr3_sequence_numbers(
        repcalc_dir,
        repertoire_groups,
        groups=[control, group],
        sample_info_df=sample_info_df,
        sharing=sharing,
        processing_stage=processing_stage
    )
    fig, axes = gr.plot_unique_number_of_cdr3(
        df,
        palette='Set2',
        figsize=(20, 6)
    )
    fig.suptitle(f"Unique number of CDR3 for {' vs '.join([control[1]+f' (N={len(control[2])})', group[1]+f' (N={len(group[2])})'])}")
    fig.tight_layout()
    # figname = f'Figures/unique_number_of_cdr3_{'_'.join(group_names)}.png'
    # plt.savefig(figname, bbox_inches = 'tight', dpi = 300)
    handles, lables = axes[1].get_legend_handles_labels()
    condition_counts = {e[1] : len(e[2]) for e in groups_tuple}
    new_labels = [f'{condition}, N={int(condition_counts[condition])}' for condition in lables]
    axes[1].legend(handles, new_labels, title='Group', loc='center left', bbox_to_anchor=(1, 0.5))
    fig.show()
